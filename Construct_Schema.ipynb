# %% [markdown]
# # Constructing Schema Notebook
#
# ### Getting all predicates
# ENPKG is too large to query over all triples to get all unique predicates. Uses a subsampling method to get all predicates.
#
# ### Constructing schema
# Constructs a schema.ttl file for the schema (all triples representing with predicates link with classes together)

# %%
# general python libs
import json
import os
from SPARQLWrapper import SPARQLWrapper, JSON, TURTLE
import glob
import rdflib
from rdflib import Graph
import tiktoken
import time

# %%
# This is the remote ENPKG SPARQL endpoint
endpoint_url = 'https://enpkg.commons-lab.org/graphdb/repositories/ENPKG'
directory = './schema'

if not os.path.exists(directory):
    os.mkdir(directory)

# %%
# HELPER FUNCTIONS

def run_sparql(query, 
               url=endpoint_url):
    sparql = SPARQLWrapper(url)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    sparql.setTimeout(600)
    results = sparql.query().convert()
    results = results['results']['bindings']
    return results

def run_sparql_construct(query, filename, url=endpoint_url):
    sparql = SPARQLWrapper(url)
    sparql.setQuery(query)
    sparql.setReturnFormat(TURTLE)
    sparql.setTimeout(600)
    results = sparql.queryAndConvert()
    graph = rdflib.Graph()
    graph.parse(data=results, format='turtle')
    graph.serialize(destination=filename, format='turtle')
    return results

# %% [markdown]
# # Get all predicates
# ## Step 1: get all classes

# %%
query = """  
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX enpkg: <https://enpkg.commons-lab.org/kg/>
select distinct ?o where { 
	# ?s a ?o .
} 
"""

# %%
classes = [x['o']['value'] for x in run_sparql(query)]

# %%
print('number of classes: ', len(classes))
    
classes
# Out:
# number of classes:  55
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#Property',
#  'http://www.w3.org/2002/07/owl#TransitiveProperty',
#  'http://www.w3.org/2002/07/owl#SymmetricProperty',
#  'http://www.w3.org/1999/02/22-rdf-syntax-ns#List',
#  'http://www.w3.org/2000/01/rdf-schema#Class',
#  'http://www.w3.org/2000/01/rdf-schema#Datatype',
#  'http://www.w3.org/2000/01/rdf-schema#ContainerMembershipProperty',
#  'https://enpkg.commons-lab.org/kg/RawMaterial',
#  'https://enpkg.commons-lab.org/kg/LabObject',
#  'http://rdfs.org/ns/void#Dataset',
#  'https://enpkg.commons-lab.org/kg/LabExtract',
#  'https://enpkg.commons-lab.org/kg/WDTaxon',
#  'https://enpkg.commons-lab.org/kg/XRef',
#  'https://enpkg.commons-lab.org/kg/LFpair',
#  'https://enpkg.commons-lab.org/kg/SpectralPair',
#  'https://enpkg.commons-lab.org/kg/LCMSFeature',
#  'https://enpkg.commons-lab.org/kg/MS2Spectrum',
#  'https://enpkg.commons-lab.org/kg/WDChemical',
#  'https://enpkg.commons-lab.org/kg/InChIkey2D',
#  'https://enpkg.commons-lab.org/kg/NPCClass',
#  'https://enpkg.commons-lab.org/kg/NPCSuperclass',
#  'https://enpkg.commons-lab.org/kg/NPCPathway',
#  'https://enpkg.commons-lab.org/kg/ChemicalTaxonomy',
#  'https://enpkg.commons-lab.org/kg/InChIkey',
#  'https://enpkg.commons-lab.org/kg/ChemicalEntity',
#  'https://enpkg.commons-lab.org/kg/LCMSAnalysisPos',
#  'https://enpkg.commons-lab.org/kg/LCMSAnalysis',
#  'https://enpkg.commons-lab.org/kg/LCMSFeatureList',
#  'https://enpkg.commons-lab.org/kg/SiriusCanopusAnnotation',
#  'https://enpkg.commons-lab.org/kg/Annotation',
#  'https://enpkg.commons-lab.org/kg/Spec2VecDoc',
#  'https://enpkg.commons-lab.org/kg/spec2vec',
#  'https://enpkg.commons-lab.org/kg/IsdbAnnotation',
#  'https://enpkg.commons-lab.org/kg/SiriusStructureAnnotation',
#  'https://enpkg.commons-lab.org/kg/Spec2VecLoss',
#  'https://enpkg.commons-lab.org/kg/Spec2VecPeak',
#  'https://enpkg.commons-lab.org/kg/LCMSAnalysisNeg',
#  'https://enpkg.commons-lab.org/module/L610ugml',
#  'https://enpkg.commons-lab.org/kg/BioAssayResults',
#  'https://enpkg.commons-lab.org/module/SwissTPHBioAssay',
#  'https://enpkg.commons-lab.org/module/Ldono10ugml',
#  'https://enpkg.commons-lab.org/module/Ldono2ugml',
#  'https://enpkg.commons-lab.org/module/Tbrucei10ugml',
#  'https://enpkg.commons-lab.org/module/Tbrucei2ugml',
#  'https://enpkg.commons-lab.org/module/Tcruzi10ugml',
#  'https://enpkg.commons-lab.org/module/ChEMBLTarget',
#  'https://enpkg.commons-lab.org/kg/LabBlank',
#  'https://enpkg.commons-lab.org/kg/LabQc',
#  'https://enpkg.commons-lab.org/module/ChEMBLChemical',
#  'https://enpkg.commons-lab.org/module/ChEMBLAssayResults',
#  'https://enpkg.commons-lab.org/module/ChEMBLAssay',
#  'https://enpkg.commons-lab.org/module/ChEMBLDocument',
#  'http://xmlns.com/foaf/0.1/Person',
#  'http://www.w3.org/2002/07/owl#Ontology',
#  'http://purl.org/dc/dcmitype/Dataset']

# %% [markdown]
# ## Step 2: get objects of each class and subsample

# %%
query2 = """  
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX enpkg: <https://enpkg.commons-lab.org/kg/>
select ?s where {{ 
	# ?s a <{cls}> .
}} ORDER BY RAND() LIMIT 100
"""

# %%
random_instances = {}
for c in classes:
    inst_output =  run_sparql(query2.format(cls = c))
    random_instances[c] = [x['s']['value'] for x in inst_output]

# %%
random_instances
# Out:
# {'http://www.w3.org/1999/02/22-rdf-syntax-ns#Property': ['http://rdfs.org/ns/void#properties',
#   'https://enpkg.commons-lab.org/kg/has_fbmn_ci',
#   'https://enpkg.commons-lab.org/kg/has_sirius_annotation_67cd1a41589bee5e1e4ccee651ddf01b',
#   'http://proton.semanticweb.org/protonsys#transitiveOver',
#   'http://example.org/has_sha256',
#   'https://enpkg.commons-lab.org/kg/has_isdb_annotation',
#   'https://enpkg.commons-lab.org/kg/has_relative_feature_area',
#   'https://enpkg.commons-lab.org/kg/has_member',
#   'https://enpkg.commons-lab.org/kg/has_LCMS',
#   'https://enpkg.commons-lab.org/kg/has_canopus_npc_class',
#   'http://www.w3.org/1999/02/22-rdf-syntax-ns#object',
#   'https://enpkg.commons-lab.org/kg/fast_search_gnpslibrary_no_analog',
#   'https://enpkg.commons-lab.org/module/target_id',
#   'https://enpkg.commons-lab.org/kg/has_content',
#   'https://enpkg.commons-lab.org/kg/has_LCMS_606e5e35b5df8d788a66e08a8f03f494',
#   'https://enpkg.commons-lab.org/kg/has_cosmic_score',
#   'https://enpkg.commons-lab.org/kg/has_sirius_annotation_aef4b4a1a4d837ba0cd2dc861c1c7edf',
#   'http://www.w3.org/1999/02/22-rdf-syntax-ns#first',
#   'https://enpkg.commons-lab.org/module/has_bioassay_results',
#   'http://purl.org/dc/terms/modified',
#   'https://enpkg.commons-lab.org/kg/has_smiles',
#   'https://enpkg.commons-lab.org/kg/has_lcms_feature_list_d5f38c47bc9e90a297d4c26ee02d05b5',
#   'https://enpkg.commons-lab.org/kg/has_wd_id_c18527bea8b2606a55457d607b24df69',
#   'https://enpkg.commons-lab.org/kg/fast_search_gnpsdata_index_analog',
#   'https://enpkg.commons-lab.org/kg/has_isdb_annotation_fd78fc9d48e5f20e49885f4a87565b9a',
#   'http://www.w3.org/2000/01/rdf-schema#domain',
#   'https://enpkg.commons-lab.org/kg/has_canopus_annotation',
#   'http://xmlns.com/foaf/0.1/depiction',
#   'http://purl.org/vocab/vann/preferredNamespacePrefix',
#   'https://enpkg.commons-lab.org/kg/is_InChIkey2D_of',
#   'https://enpkg.commons-lab.org/kg/has_wd_id_1a78e7ba3a4b0616999e360a0f8477e1',
#   'https://enpkg.commons-lab.org/kg/has_feature_area',
#   'https://enpkg.commons-lab.org/kg/has_usi',
#   'https://enpkg.commons-lab.org/kg/has_lcms_feature',
#   'https://enpkg.commons-lab.org/kg/has_lab_process',
#   'https://enpkg.commons-lab.org/kg/has_LCMS_41c2dacf4cb75801e3c2fd01ab8d599d',
#   'https://enpkg.commons-lab.org/kg/fast_search_gnpslibrary_analog',
#   'https://enpkg.commons-lab.org/kg/has_lcms_feature_list',
#   'https://enpkg.commons-lab.org/kg/has_parent_mass',
#   'https://enpkg.commons-lab.org/kg/has_ionization',
#   'https://enpkg.commons-lab.org/kg/has_sirius_score',
#   'http://schema.org/affiliation',
#   'https://enpkg.commons-lab.org/kg/gnps_dashboard_view',
#   'https://enpkg.commons-lab.org/kg/has_retention_time',
#   'https://enpkg.commons-lab.org/kg/has_spectral_score',
#   'http://purl.org/dc/terms/hasPart',
#   'http://schema.org/email',
#   'https://enpkg.commons-lab.org/kg/has_massive_license',
#   'http://www.w3.org/2000/01/rdf-schema#subClassOf',
#   'https://enpkg.commons-lab.org/kg/has_raw_spectrum',
#   'https://enpkg.commons-lab.org/kg/has_npc_class',
#   'https://enpkg.commons-lab.org/kg/has_wd_id_58188f7fc5732f02a13169efb6cbd254',
#   'https://enpkg.commons-lab.org/kg/has_isdb_annotation_f4fec9f496001612d60a75b5e1a43991',
#   'https://enpkg.commons-lab.org/kg/has_cosine',
#   'https://enpkg.commons-lab.org/kg/has_lcms_feature_list_a6a5420d414df1000ab74a2b82275839',
#   'https://enpkg.commons-lab.org/kg/has_spec2vec_doc',
#   'http://www.w3.org/1999/02/22-rdf-syntax-ns#type',
#   'https://enpkg.commons-lab.org/kg/has_spec2vec_loss',
#   'https://enpkg.commons-lab.org/kg/has_isdb_annotation_8a8c6af3837c0b5e86a3b445528db176',
#   'http://rdfs.org/ns/void#dataDump',
#   'https://enpkg.commons-lab.org/kg/submitted_taxon',
#   'http://rdfs.org/ns/void#triples',
#   'http://purl.org/pav/hasCurrentVersion',
#   'https://enpkg.commons-lab.org/kg/has_adduct',
#   'https://enpkg.commons-lab.org/kg/has_final_score',
#   'https://enpkg.commons-lab.org/kg/has_mass_difference',
#   'http://purl.org/dc/terms/issued',
#   'http://www.w3.org/1999/02/22-rdf-syntax-ns#predicate',
#   'https://enpkg.commons-lab.org/kg/has_sirius_annotation_134c8d71fc127e80bf11783c63ca2a6a',
#   'https://enpkg.commons-lab.org/module/has_tissue',
#   'https://enpkg.commons-lab.org/kg/has_member_1',
#   'https://enpkg.commons-lab.org/kg/has_npc_superclass',
#   'https://enpkg.commons-lab.org/kg/has_LCMS_a3d5d65516c4504ea94e2d82b8926826',
#   'http://www.w3.org/2000/01/rdf-schema#range',
#   'https://enpkg.commons-lab.org/kg/has_lcms_feature_list_a137fd4a263d3587d35f61a526932c09',
#   'https://enpkg.commons-lab.org/module/has_broad_organe',
#   'https://enpkg.commons-lab.org/kg/has_spec2vec_peak',
#   'https://enpkg.commons-lab.org/kg/has_zodiac_score',
#   'https://enpkg.commons-lab.org/kg/has_taxo_score',
#   'http://rdfs.org/ns/void#distinctObjects',
#   'https://enpkg.commons-lab.org/kg/has_InChIkey2D',
#   'https://enpkg.commons-lab.org/kg/has_LCMS_115a7a437b9e53c614dfed0c7c2ae3eb',
#   'http://purl.org/pav/version',
#   'https://enpkg.commons-lab.org/kg/has_isdb_annotation_95a24ed68ee3b548d93d96b99ba630c4',
#   'http://www.w3.org/2000/01/rdf-schema#comment',
#   'https://enpkg.commons-lab.org/kg/has_row_id',
#   'https://enpkg.commons-lab.org/kg/has_canopus_annotation_00c339c3b183cb7fbf466b4d334dbef2',
#   'https://enpkg.commons-lab.org/kg/has_value',
#   'http://purl.org/dc/terms/accrualPeriodicity',
#   'https://enpkg.commons-lab.org/kg/has_gnpslcms_link',
#   'https://enpkg.commons-lab.org/kg/has_canopus_npc_superclass_prob',
#   'http://purl.org/dc/terms/contributor',
#   'https://enpkg.commons-lab.org/module/target_name',
#   'http://www.w3.org/2000/01/rdf-schema#subPropertyOf',
#   'http://purl.org/dc/terms/description',
#   'https://enpkg.commons-lab.org/kg/has_sirius_adduct',
#   'http://www.w3.org/2002/07/owl#versionInfo',
#   'https://enpkg.commons-lab.org/kg/has_wd_id',
#   'https://enpkg.commons-lab.org/module/activity_value',
#   'https://enpkg.commons-lab.org/kg/has_canopus_npc_pathway'],
#  'http://www.w3.org/2002/07/owl#TransitiveProperty': ['http://www.w3.org/2000/01/rdf-schema#subClassOf',
#   'http://www.w3.org/2002/07/owl#equivalentClass',
#   'http://www.w3.org/2000/01/rdf-schema#subPropertyOf',
#   'http://www.w3.org/2002/07/owl#equivalentProperty'],
#  'http://www.w3.org/2002/07/owl#SymmetricProperty': ['http://www.w3.org/2002/07/owl#inverseOf',
#   'http://www.w3.org/2002/07/owl#equivalentProperty',
#   'http://www.w3.org/2002/07/owl#equivalentClass',
#   'http://www.w3.org/2002/07/owl#differentFrom'],
#  'http://www.w3.org/1999/02/22-rdf-syntax-ns#List': ['http://www.w3.org/1999/02/22-rdf-syntax-ns#nil'],
#  'http://www.w3.org/2000/01/rdf-schema#Class': ['https://enpkg.commons-lab.org/module/Tbrucei2ugml',
#   'https://enpkg.commons-lab.org/kg/BioAssayResults',
#   'https://enpkg.commons-lab.org/kg/NPCSuperclass',
#   'https://enpkg.commons-lab.org/kg/MS2Spectrum',
#   'https://enpkg.commons-lab.org/kg/LabBlank',
#   'https://enpkg.commons-lab.org/kg/Spec2VecDoc',
#   'https://enpkg.commons-lab.org/kg/LabQc',
#   'https://enpkg.commons-lab.org/kg/NPCClass',
#   'https://enpkg.commons-lab.org/kg/spec2vec',
#   'https://enpkg.commons-lab.org/module/ChEMBLAssayResults',
#   'https://enpkg.commons-lab.org/kg/InChIkey',
#   'http://www.w3.org/2001/XMLSchema#string',
#   'https://enpkg.commons-lab.org/kg/InChIkey2D',
#   'https://enpkg.commons-lab.org/kg/SiriusCanopusAnnotation',
#   'https://enpkg.commons-lab.org/kg/LCMSAnalysis',
#   'https://enpkg.commons-lab.org/kg/Annotation',
#   'https://enpkg.commons-lab.org/module/Ldono10ugml',
#   'https://enpkg.commons-lab.org/kg/NPCPathway',
#   'https://enpkg.commons-lab.org/kg/LFpair',
#   'https://enpkg.commons-lab.org/module/ChEMBLTarget',
#   'https://enpkg.commons-lab.org/module/ChEMBLAssay',
#   'https://enpkg.commons-lab.org/kg/GNPSAnnotation',
#   'https://enpkg.commons-lab.org/kg/LCMSAnalysisPos',
#   'https://enpkg.commons-lab.org/module/L610ugml',
#   'http://www.w3.org/1999/02/22-rdf-syntax-ns#XMLLiteral',
#   'https://enpkg.commons-lab.org/kg/XRef',
#   'https://enpkg.commons-lab.org/kg/Spec2VecPeak',
#   'https://enpkg.commons-lab.org/module/ChEMBLChemical',
#   'https://enpkg.commons-lab.org/kg/WDTaxon',
#   'https://enpkg.commons-lab.org/kg/LCMSAnalysisNeg',
#   'https://enpkg.commons-lab.org/module/Tbrucei10ugml',
#   'https://enpkg.commons-lab.org/kg/LCMSFeature',
#   'https://enpkg.commons-lab.org/kg/WDChemical',
#   'https://enpkg.commons-lab.org/module/ChEMBLDocument',
#   'https://enpkg.commons-lab.org/kg/LabExtract',
#   'https://enpkg.commons-lab.org/module/Tcruzi10ugml',
#   'https://enpkg.commons-lab.org/kg/SpectralPair',
#   'https://enpkg.commons-lab.org/kg/ChemicalEntity',
#   'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#   'https://enpkg.commons-lab.org/module/SwissTPHBioAssay',
#   'https://enpkg.commons-lab.org/kg/ChemicalTaxonomy',
#   'https://enpkg.commons-lab.org/kg/LCMSFeatureList',
#   'https://enpkg.commons-lab.org/module/Ldono2ugml',
#   'https://enpkg.commons-lab.org/kg/RawMaterial',
#   'https://enpkg.commons-lab.org/kg/IsdbAnnotation',
#   'https://enpkg.commons-lab.org/kg/SiriusStructureAnnotation',
#   'https://enpkg.commons-lab.org/kg/Spec2VecLoss',
#   'https://enpkg.commons-lab.org/kg/LabObject'],
#  'http://www.w3.org/2000/01/rdf-schema#Datatype': ['http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#   'http://www.w3.org/2001/XMLSchema#string',
#   'http://www.w3.org/1999/02/22-rdf-syntax-ns#XMLLiteral'],
#  'http://www.w3.org/2000/01/rdf-schema#ContainerMembershipProperty': ['http://www.w3.org/1999/02/22-rdf-syntax-ns#_1'],
#  'https://enpkg.commons-lab.org/kg/RawMaterial': ['https://enpkg.commons-lab.org/kg/V112085GP-01',
#   'https://enpkg.commons-lab.org/kg/V112347GP-01',
#   'https://enpkg.commons-lab.org/kg/V112091GP-01',
#   'https://enpkg.commons-lab.org/kg/V112217GP-01',
#   'https://enpkg.commons-lab.org/kg/V112858GP-01',
#   'https://enpkg.commons-lab.org/kg/V112089GP-01',
#   'https://enpkg.commons-lab.org/kg/V112862GP-01',
#   'https://enpkg.commons-lab.org/kg/V112860GP-01',
#   'https://enpkg.commons-lab.org/kg/V112290GP-01',
#   'https://enpkg.commons-lab.org/kg/V111983GP-01',
#   'https://enpkg.commons-lab.org/kg/V112312GP-01',
#   'https://enpkg.commons-lab.org/kg/V112215GP-01',
#   'https://enpkg.commons-lab.org/kg/V112414GP-01',
#   'https://enpkg.commons-lab.org/kg/V112292GP-01',
#   'https://enpkg.commons-lab.org/kg/V113101GP-01',
#   'https://enpkg.commons-lab.org/kg/V112101GP-01',
#   'https://enpkg.commons-lab.org/kg/V113985GP-01',
#   'https://enpkg.commons-lab.org/kg/V112080GP-01',
#   'https://enpkg.commons-lab.org/kg/V112203GP-01',
#   'https://enpkg.commons-lab.org/kg/V112049GP-01',
#   'https://enpkg.commons-lab.org/kg/V112028GP-01',
#   'https://enpkg.commons-lab.org/kg/V112108GP-01',
#   'https://enpkg.commons-lab.org/kg/V111998GP-01',
#   'https://enpkg.commons-lab.org/kg/V112015GP-01',
#   'https://enpkg.commons-lab.org/kg/V113004GP-01',
#   'https://enpkg.commons-lab.org/kg/V112944GP-01',
#   'https://enpkg.commons-lab.org/kg/V112354GP-01',
#   'https://enpkg.commons-lab.org/kg/V112882GP-01',
#   'https://enpkg.commons-lab.org/kg/V112300GP-01',
#   'https://enpkg.commons-lab.org/kg/V113302GP-01',
#   'https://enpkg.commons-lab.org/kg/V113149GP-01',
#   'https://enpkg.commons-lab.org/kg/V112293GP-01',
#   'https://enpkg.commons-lab.org/kg/V113861GP-01',
#   'https://enpkg.commons-lab.org/kg/V112391GP-01',
#   'https://enpkg.commons-lab.org/kg/V112119GP-01',
#   'https://enpkg.commons-lab.org/kg/V112022GP-01',
#   'https://enpkg.commons-lab.org/kg/V113250GP-01',
#   'https://enpkg.commons-lab.org/kg/walth_ind_roots',
#   'https://enpkg.commons-lab.org/kg/V111986GP-01',
#   'https://enpkg.commons-lab.org/kg/V112055GP-01',
#   'https://enpkg.commons-lab.org/kg/V113161GP-01',
#   'https://enpkg.commons-lab.org/kg/V114431GP-01',
#   'https://enpkg.commons-lab.org/kg/V112045GP-01',
#   'https://enpkg.commons-lab.org/kg/V112272GP-01',
#   'https://enpkg.commons-lab.org/kg/V113180GP-01',
#   'https://enpkg.commons-lab.org/kg/V112327GP-01',
#   'https://enpkg.commons-lab.org/kg/V113279GP-01',
#   'https://enpkg.commons-lab.org/kg/V112102GP-01',
#   'https://enpkg.commons-lab.org/kg/V111991GP-01',
#   'https://enpkg.commons-lab.org/kg/V113240GP-01',
#   'https://enpkg.commons-lab.org/kg/V112078GP-01',
#   'https://enpkg.commons-lab.org/kg/V112100GP-01',
#   'https://enpkg.commons-lab.org/kg/V112927GP-01',
#   'https://enpkg.commons-lab.org/kg/V113203GP-01',
#   'https://enpkg.commons-lab.org/kg/V112039GP-01',
#   'https://enpkg.commons-lab.org/kg/V112373GP-01',
#   'https://enpkg.commons-lab.org/kg/V113338GP-01',
#   'https://enpkg.commons-lab.org/kg/V112322GP-01',
#   'https://enpkg.commons-lab.org/kg/V112036GP-01',
#   'https://enpkg.commons-lab.org/kg/V112281GP-01',
#   'https://enpkg.commons-lab.org/kg/V112883GP-01',
#   'https://enpkg.commons-lab.org/kg/V113217GP-01',
#   'https://enpkg.commons-lab.org/kg/V112116GP-01',
#   'https://enpkg.commons-lab.org/kg/V112287GP-01',
#   'https://enpkg.commons-lab.org/kg/V114140GP-01',
#   'https://enpkg.commons-lab.org/kg/V112068GP-01',
#   'https://enpkg.commons-lab.org/kg/V112356GP-01',
#   'https://enpkg.commons-lab.org/kg/V111820GP-01',
#   'https://enpkg.commons-lab.org/kg/V112019GP-01',
#   'https://enpkg.commons-lab.org/kg/V113024GP-01',
#   'https://enpkg.commons-lab.org/kg/V112310GP-01',
#   'https://enpkg.commons-lab.org/kg/V113389GP-01',
#   'https://enpkg.commons-lab.org/kg/V112309GP-01',
#   'https://enpkg.commons-lab.org/kg/V112896GP-01',
#   'https://enpkg.commons-lab.org/kg/V113183GP-01',
#   'https://enpkg.commons-lab.org/kg/V112895GP-01',
#   'https://enpkg.commons-lab.org/kg/V112264GP-01',
#   'https://enpkg.commons-lab.org/kg/V112344GP-01',
#   'https://enpkg.commons-lab.org/kg/V113114GP-01',
#   'https://enpkg.commons-lab.org/kg/V112873GP-01',
#   'https://enpkg.commons-lab.org/kg/V112286GP-01',
#   'https://enpkg.commons-lab.org/kg/V112274GP-01',
#   'https://enpkg.commons-lab.org/kg/V112308GP-01',
#   'https://enpkg.commons-lab.org/kg/V112983GP-01',
#   'https://enpkg.commons-lab.org/kg/V112328GP-01',
#   'https://enpkg.commons-lab.org/kg/V112010GP-01',
#   'https://enpkg.commons-lab.org/kg/V113018GP-01',
#   'https://enpkg.commons-lab.org/kg/V112179GP-01',
#   'https://enpkg.commons-lab.org/kg/V113040GP-01',
#   'https://enpkg.commons-lab.org/kg/V112062GP-01',
#   'https://enpkg.commons-lab.org/kg/V111819GP-01',
#   'https://enpkg.commons-lab.org/kg/V112269GP-01',
#   'https://enpkg.commons-lab.org/kg/V112928GP-01',
#   'https://enpkg.commons-lab.org/kg/V111987GP-01',
#   'https://enpkg.commons-lab.org/kg/V112071GP-01',
#   'https://enpkg.commons-lab.org/kg/V112057GP-01',
#   'https://enpkg.commons-lab.org/kg/V114312GP-01',
#   'https://enpkg.commons-lab.org/kg/V112406GP-01',
#   'https://enpkg.commons-lab.org/kg/V112887GP-01',
#   'https://enpkg.commons-lab.org/kg/V113045GP-01'],
#  'https://enpkg.commons-lab.org/kg/LabObject': ['https://enpkg.commons-lab.org/kg/V112356GP-01',
#   'https://enpkg.commons-lab.org/kg/VGF138_B08',
#   'https://enpkg.commons-lab.org/kg/VGF138_G05',
#   'https://enpkg.commons-lab.org/kg/VGF138_G06',
#   'https://enpkg.commons-lab.org/kg/VGF140_D04',
#   'https://enpkg.commons-lab.org/kg/VGF138_H01',
#   'https://enpkg.commons-lab.org/kg/V112019GP-01',
#   'https://enpkg.commons-lab.org/kg/V112041GP-01',
#   'https://enpkg.commons-lab.org/kg/VGF140_D09',
#   'https://enpkg.commons-lab.org/kg/V112269GP-01',
#   'https://enpkg.commons-lab.org/kg/V112359GP-01',
#   'https://enpkg.commons-lab.org/kg/V112307GP-01',
#   'https://enpkg.commons-lab.org/kg/VGF139_F06',
#   'https://enpkg.commons-lab.org/kg/VGF138_H07',
#   'https://enpkg.commons-lab.org/kg/V112323GP-01',
#   'https://enpkg.commons-lab.org/kg/V112333GP-01',
#   'https://enpkg.commons-lab.org/kg/VGF142_F06',
#   'https://enpkg.commons-lab.org/kg/V112080GP-01',
#   'https://enpkg.commons-lab.org/kg/VGF140_B07',
#   'https://enpkg.commons-lab.org/kg/V112262GP-01',
#   'https://enpkg.commons-lab.org/kg/VGF138_D01',
#   'https://enpkg.commons-lab.org/kg/VGF138_D06',
#   'https://enpkg.commons-lab.org/kg/VGF138_C01',
#   'https://enpkg.commons-lab.org/kg/V112100GP-01',
#   'https://enpkg.commons-lab.org/kg/V112031GP-01',
#   'https://enpkg.commons-lab.org/kg/VGF140_H06',
#   'https://enpkg.commons-lab.org/kg/V112344GP-01',
#   'https://enpkg.commons-lab.org/kg/VGF138_E11',
#   'https://enpkg.commons-lab.org/kg/V112311GP-01',
#   'https://enpkg.commons-lab.org/kg/V112977GP-01',
#   'https://enpkg.commons-lab.org/kg/VGF138_H06',
#   'https://enpkg.commons-lab.org/kg/V112888GP-01',
#   'https://enpkg.commons-lab.org/kg/VGF138_F12',
#   'https://enpkg.commons-lab.org/kg/VGF139_A04',
#   'https://enpkg.commons-lab.org/kg/VGF138_H08',
#   'https://enpkg.commons-lab.org/kg/VGF144_B12',
#   'https://enpkg.commons-lab.org/kg/V112058GP-01',
#   'https://enpkg.commons-lab.org/kg/VGF138_C02',
#   'https://enpkg.commons-lab.org/kg/VGF138_A05',
#   'https://enpkg.commons-lab.org/kg/VGF139_G04',
#   'https://enpkg.commons-lab.org/kg/VGF138_F08',
#   'https://enpkg.commons-lab.org/kg/VGF139_B11',
#   'https://enpkg.commons-lab.org/kg/V112286GP-01',
#   'https://enpkg.commons-lab.org/kg/V112336GP-01',
#   'https://enpkg.commons-lab.org/kg/VGF138_C12',
#   'https://enpkg.commons-lab.org/kg/VGF139_C05',
#   'https://enpkg.commons-lab.org/kg/VGF140_G04',
#   'https://enpkg.commons-lab.org/kg/VGF138_A02',
#   'https://enpkg.commons-lab.org/kg/VGF138_D04',
#   'https://enpkg.commons-lab.org/kg/VGF140_D03',
#   'https://enpkg.commons-lab.org/kg/VGF139_E06',
#   'https://enpkg.commons-lab.org/kg/VGF138_C04',
#   'https://enpkg.commons-lab.org/kg/V112401GP-01',
#   'https://enpkg.commons-lab.org/kg/VGF138_G01',
#   'https://enpkg.commons-lab.org/kg/V112390GP-01',
#   'https://enpkg.commons-lab.org/kg/V112144GP-01',
#   'https://enpkg.commons-lab.org/kg/VGF138_E12',
#   'https://enpkg.commons-lab.org/kg/VGF142_G05',
#   'https://enpkg.commons-lab.org/kg/V113040GP-01',
#   'https://enpkg.commons-lab.org/kg/VGF139_H02',
#   'https://enpkg.commons-lab.org/kg/V112045GP-01',
#   'https://enpkg.commons-lab.org/kg/VGF139_D04',
#   'https://enpkg.commons-lab.org/kg/LP_P03_36',
#   'https://enpkg.commons-lab.org/kg/V112270GP-01',
#   'https://enpkg.commons-lab.org/kg/VGF138_E06',
#   'https://enpkg.commons-lab.org/kg/VGF141_G09',
#   'https://enpkg.commons-lab.org/kg/VGF138_G11',
#   'https://enpkg.commons-lab.org/kg/V112065GP-01',
#   'https://enpkg.commons-lab.org/kg/V112865GP-01',
#   'https://enpkg.commons-lab.org/kg/VGF138_E07',
#   'https://enpkg.commons-lab.org/kg/V112276GP-01',
#   'https://enpkg.commons-lab.org/kg/VGF140_E06',
#   'https://enpkg.commons-lab.org/kg/LP_P03_35',
#   'https://enpkg.commons-lab.org/kg/VGF139_G10',
#   'https://enpkg.commons-lab.org/kg/VGF139_H05',
#   'https://enpkg.commons-lab.org/kg/VGF138_H11',
#   'https://enpkg.commons-lab.org/kg/V112268GP-01',
#   'https://enpkg.commons-lab.org/kg/VGF138_D02',
#   'https://enpkg.commons-lab.org/kg/V113429GP-01',
#   'https://enpkg.commons-lab.org/kg/V112104GP-01',
#   'https://enpkg.commons-lab.org/kg/VGF140_G10',
#   'https://enpkg.commons-lab.org/kg/V112036GP-01',
#   'https://enpkg.commons-lab.org/kg/V112048GP-01',
#   'https://enpkg.commons-lab.org/kg/V112302GP-01',
#   'https://enpkg.commons-lab.org/kg/V113131GP-01',
#   'https://enpkg.commons-lab.org/kg/V112062GP-01',
#   'https://enpkg.commons-lab.org/kg/V112108GP-01',
#   'https://enpkg.commons-lab.org/kg/V112035GP-01',
#   'https://enpkg.commons-lab.org/kg/VGF139_A02',
#   'https://enpkg.commons-lab.org/kg/V113052GP-01',
#   'https://enpkg.commons-lab.org/kg/V112373GP-01',
#   'https://enpkg.commons-lab.org/kg/VGF138_B03',
#   'https://enpkg.commons-lab.org/kg/walth_ind_aerparts',
#   'https://enpkg.commons-lab.org/kg/VGF138_B06',
#   'https://enpkg.commons-lab.org/kg/VGF138_F01',
#   'https://enpkg.commons-lab.org/kg/VGF141_F04',
#   'https://enpkg.commons-lab.org/kg/VGF139_H11',
#   'https://enpkg.commons-lab.org/kg/VGF138_E05',
#   'https://enpkg.commons-lab.org/kg/VGF138_G10',
#   'https://enpkg.commons-lab.org/kg/VGF139_A05'],
#  'http://rdfs.org/ns/void#Dataset': ['https://enpkg.commons-lab.org/kg/PF1600_VGF146',
#   'https://enpkg.commons-lab.org/kg/PF1600_VGF155',
#   'https://enpkg.commons-lab.org/kg/PF1600_VGF141',
#   'https://enpkg.commons-lab.org/kg/PF1600_VGF157',
#   'https://enpkg.commons-lab.org/kg/PF1600_VGF156',
#   'https://enpkg.commons-lab.org/kg/PF1600_VGF151',
#   'https://enpkg.commons-lab.org/kg/PF1600_VGF145',
#   'https://enpkg.commons-lab.org/kg/MSV000093464_batch_02',
#   'https://enpkg.commons-lab.org/kg/SETUP',
#   'https://enpkg.commons-lab.org/kg/PF1600_VGF159',
#   'https://enpkg.commons-lab.org/kg/PF1600_VGF143',
#   'https://enpkg.commons-lab.org/kg/PF1600_VGF142',
#   'https://enpkg.commons-lab.org/kg/IMAGE_LINK',
#   'https://enpkg.commons-lab.org/kg/WALTHERIA',
#   'https://enpkg.commons-lab.org/kg/MSV000093464_batch_01',
#   'https://enpkg.commons-lab.org/kg/PF1600_VGF138',
#   'https://enpkg.commons-lab.org/kg/PF1600_VGF154',
#   'https://enpkg.commons-lab.org/kg/MSV000093464_batch_04',
#   'https://enpkg.commons-lab.org/kg/PF1600_VGF139',
#   'https://enpkg.commons-lab.org/kg/PF1600_VGF152',
#   'https://enpkg.commons-lab.org/kg/MSV000093464_batch_03',
#   'https://enpkg.commons-lab.org/kg/PF1600_VGF144',
#   'https://enpkg.commons-lab.org/kg/SCHEMA',
#   'https://enpkg.commons-lab.org/kg/CHEMBL',
#   'https://enpkg.commons-lab.org/kg/PF1600_VGF150',
#   'https://enpkg.commons-lab.org/kg/PF1600_VGF158',
#   'https://enpkg.commons-lab.org/kg/PF1600_VGF140',
#   'https://enpkg.commons-lab.org/kg/PF1600_VGF153',
#   'https://enpkg.commons-lab.org/kg/PF1600_VGF147'],
#  'https://enpkg.commons-lab.org/kg/LabExtract': ['https://enpkg.commons-lab.org/kg/VGF139_C08',
#   'https://enpkg.commons-lab.org/kg/VGF140_F02',
#   'https://enpkg.commons-lab.org/kg/VGF138_G09',
#   'https://enpkg.commons-lab.org/kg/VGF142_G10',
#   'https://enpkg.commons-lab.org/kg/VGF141_F11',
#   'https://enpkg.commons-lab.org/kg/VGF141_F07',
#   'https://enpkg.commons-lab.org/kg/VGF139_D08',
#   'https://enpkg.commons-lab.org/kg/VGF142_D02',
#   'https://enpkg.commons-lab.org/kg/VGF140_G06',
#   'https://enpkg.commons-lab.org/kg/VGF146_C05',
#   'https://enpkg.commons-lab.org/kg/VGF139_E02',
#   'https://enpkg.commons-lab.org/kg/VGF138_F06',
#   'https://enpkg.commons-lab.org/kg/VGF139_E05',
#   'https://enpkg.commons-lab.org/kg/VGF143_H03',
#   'https://enpkg.commons-lab.org/kg/VGF139_B08',
#   'https://enpkg.commons-lab.org/kg/VGF138_C03',
#   'https://enpkg.commons-lab.org/kg/VGF140_A06',
#   'https://enpkg.commons-lab.org/kg/VGF138_C10',
#   'https://enpkg.commons-lab.org/kg/VGF146_A02',
#   'https://enpkg.commons-lab.org/kg/VGF142_G08',
#   'https://enpkg.commons-lab.org/kg/VGF139_A02',
#   'https://enpkg.commons-lab.org/kg/VGF138_F05',
#   'https://enpkg.commons-lab.org/kg/VGF138_H07',
#   'https://enpkg.commons-lab.org/kg/VGF141_E02',
#   'https://enpkg.commons-lab.org/kg/VGF138_B07',
#   'https://enpkg.commons-lab.org/kg/VGF142_C04',
#   'https://enpkg.commons-lab.org/kg/VGF138_H06',
#   'https://enpkg.commons-lab.org/kg/VGF142_B03',
#   'https://enpkg.commons-lab.org/kg/VGF138_G08',
#   'https://enpkg.commons-lab.org/kg/VGF145_H02',
#   'https://enpkg.commons-lab.org/kg/VGF139_F11',
#   'https://enpkg.commons-lab.org/kg/VGF139_D06',
#   'https://enpkg.commons-lab.org/kg/VGF145_E07',
#   'https://enpkg.commons-lab.org/kg/VGF138_G07',
#   'https://enpkg.commons-lab.org/kg/VGF140_E05',
#   'https://enpkg.commons-lab.org/kg/VGF141_H06',
#   'https://enpkg.commons-lab.org/kg/VGF139_G02',
#   'https://enpkg.commons-lab.org/kg/VGF139_B10',
#   'https://enpkg.commons-lab.org/kg/VGF145_B09',
#   'https://enpkg.commons-lab.org/kg/VGF140_A05',
#   'https://enpkg.commons-lab.org/kg/VGF143_H09',
#   'https://enpkg.commons-lab.org/kg/VGF144_D09',
#   'https://enpkg.commons-lab.org/kg/VGF142_C03',
#   'https://enpkg.commons-lab.org/kg/VGF144_H09',
#   'https://enpkg.commons-lab.org/kg/VGF138_A06',
#   'https://enpkg.commons-lab.org/kg/VGF141_H05',
#   'https://enpkg.commons-lab.org/kg/VGF138_A05',
#   'https://enpkg.commons-lab.org/kg/VGF138_C07',
#   'https://enpkg.commons-lab.org/kg/VGF138_B05',
#   'https://enpkg.commons-lab.org/kg/VGF150_E11',
#   'https://enpkg.commons-lab.org/kg/VGF139_H03',
#   'https://enpkg.commons-lab.org/kg/VGF139_H04',
#   'https://enpkg.commons-lab.org/kg/VGF143_F04',
#   'https://enpkg.commons-lab.org/kg/VGF139_D10',
#   'https://enpkg.commons-lab.org/kg/VGF150_F06',
#   'https://enpkg.commons-lab.org/kg/VGF141_B02',
#   'https://enpkg.commons-lab.org/kg/VGF140_F08',
#   'https://enpkg.commons-lab.org/kg/VGF142_D10',
#   'https://enpkg.commons-lab.org/kg/VGF139_D04',
#   'https://enpkg.commons-lab.org/kg/VGF139_A05',
#   'https://enpkg.commons-lab.org/kg/VGF139_C11',
#   'https://enpkg.commons-lab.org/kg/VGF138_C02',
#   'https://enpkg.commons-lab.org/kg/VGF140_B09',
#   'https://enpkg.commons-lab.org/kg/VGF141_G03',
#   'https://enpkg.commons-lab.org/kg/VGF142_A08',
#   'https://enpkg.commons-lab.org/kg/VGF140_E03',
#   'https://enpkg.commons-lab.org/kg/VGF140_B08',
#   'https://enpkg.commons-lab.org/kg/VGF138_E11',
#   'https://enpkg.commons-lab.org/kg/VGF141_G07',
#   'https://enpkg.commons-lab.org/kg/VGF138_A10',
#   'https://enpkg.commons-lab.org/kg/VGF155_A07',
#   'https://enpkg.commons-lab.org/kg/VGF138_F09',
#   'https://enpkg.commons-lab.org/kg/VGF138_D11',
#   'https://enpkg.commons-lab.org/kg/VGF146_G05',
#   'https://enpkg.commons-lab.org/kg/VGF140_F07',
#   'https://enpkg.commons-lab.org/kg/VGF140_G09',
#   'https://enpkg.commons-lab.org/kg/VGF139_A06',
#   'https://enpkg.commons-lab.org/kg/VGF140_G07',
#   'https://enpkg.commons-lab.org/kg/VGF151_E09',
#   'https://enpkg.commons-lab.org/kg/VGF139_B02',
#   'https://enpkg.commons-lab.org/kg/VGF139_G03',
#   'https://enpkg.commons-lab.org/kg/VGF138_D03',
#   'https://enpkg.commons-lab.org/kg/VGF139_E03',
#   'https://enpkg.commons-lab.org/kg/VGF139_H06',
#   'https://enpkg.commons-lab.org/kg/VGF143_F02',
#   'https://enpkg.commons-lab.org/kg/VGF138_E08',
#   'https://enpkg.commons-lab.org/kg/VGF138_G11',
#   'https://enpkg.commons-lab.org/kg/VGF139_E04',
#   'https://enpkg.commons-lab.org/kg/VGF139_E07',
#   'https://enpkg.commons-lab.org/kg/VGF139_D09',
#   'https://enpkg.commons-lab.org/kg/VGF142_D08',
#   'https://enpkg.commons-lab.org/kg/VGF141_F05',
#   'https://enpkg.commons-lab.org/kg/VGF138_H09',
#   'https://enpkg.commons-lab.org/kg/VGF139_E08',
#   'https://enpkg.commons-lab.org/kg/VGF138_E10',
#   'https://enpkg.commons-lab.org/kg/VGF139_H05',
#   'https://enpkg.commons-lab.org/kg/LP_P03_36',
#   'https://enpkg.commons-lab.org/kg/VGF142_E07',
#   'https://enpkg.commons-lab.org/kg/VGF138_G10',
#   'https://enpkg.commons-lab.org/kg/VGF138_E09'],
#  'https://enpkg.commons-lab.org/kg/WDTaxon': ['http://www.wikidata.org/entity/Q960124',
#   'http://www.wikidata.org/entity/Q13399160',
#   'http://www.wikidata.org/entity/Q11179632',
#   'http://www.wikidata.org/entity/Q11092941',
#   'http://www.wikidata.org/entity/Q5834167',
#   'http://www.wikidata.org/entity/Q15226025',
#   'http://www.wikidata.org/entity/Q104252526',
#   'http://www.wikidata.org/entity/Q12234248',
#   'http://www.wikidata.org/entity/Q21321499',
#   'http://www.wikidata.org/entity/Q1786657',
#   'http://www.wikidata.org/entity/Q15525182',
#   'http://www.wikidata.org/entity/Q35905',
#   'http://www.wikidata.org/entity/Q8248272',
#   'http://www.wikidata.org/entity/Q15234525',
#   'http://www.wikidata.org/entity/Q941464',
#   'http://www.wikidata.org/entity/Q5875385',
#   'http://www.wikidata.org/entity/Q15382507',
#   'http://www.wikidata.org/entity/Q161697',
#   'http://www.wikidata.org/entity/Q15245760',
#   'http://www.wikidata.org/entity/Q5399660',
#   'http://www.wikidata.org/entity/Q2265513',
#   'http://www.wikidata.org/entity/Q8287860',
#   'http://www.wikidata.org/entity/Q5228375',
#   'http://www.wikidata.org/entity/Q17715850',
#   'http://www.wikidata.org/entity/Q4961812',
#   'http://www.wikidata.org/entity/Q15479996',
#   'http://www.wikidata.org/entity/Q2544575',
#   'http://www.wikidata.org/entity/Q15367606',
#   'http://www.wikidata.org/entity/Q157763',
#   'http://www.wikidata.org/entity/Q15240593',
#   'http://www.wikidata.org/entity/Q161111',
#   'http://www.wikidata.org/entity/Q3011617',
#   'http://www.wikidata.org/entity/Q27164',
#   'http://www.wikidata.org/entity/Q15588162',
#   'http://www.wikidata.org/entity/Q5168282',
#   'http://www.wikidata.org/entity/Q10924975',
#   'http://www.wikidata.org/entity/Q15433964',
#   'http://www.wikidata.org/entity/Q11108729',
#   'http://www.wikidata.org/entity/Q3280527',
#   'http://www.wikidata.org/entity/Q9334552',
#   'http://www.wikidata.org/entity/Q17024094',
#   'http://www.wikidata.org/entity/Q15473516',
#   'http://www.wikidata.org/entity/Q15530962',
#   'http://www.wikidata.org/entity/Q13909581',
#   'http://www.wikidata.org/entity/Q5787832',
#   'http://www.wikidata.org/entity/Q10926414',
#   'http://www.wikidata.org/entity/Q15388338',
#   'http://www.wikidata.org/entity/Q10891749',
#   'http://www.wikidata.org/entity/Q11291736',
#   'http://www.wikidata.org/entity/Q11035684',
#   'http://www.wikidata.org/entity/Q11120322',
#   'http://www.wikidata.org/entity/Q657997',
#   'http://www.wikidata.org/entity/Q3339098',
#   'http://www.wikidata.org/entity/Q15393809',
#   'http://www.wikidata.org/entity/Q161436',
#   'http://www.wikidata.org/entity/Q3205665',
#   'http://www.wikidata.org/entity/Q15376229',
#   'http://www.wikidata.org/entity/Q43372103',
#   'http://www.wikidata.org/entity/Q17247030',
#   'http://www.wikidata.org/entity/Q158596',
#   'http://www.wikidata.org/entity/Q13635748',
#   'http://www.wikidata.org/entity/Q4217123',
#   'http://www.wikidata.org/entity/Q900986',
#   'http://www.wikidata.org/entity/Q15394549',
#   'http://www.wikidata.org/entity/Q11238988',
#   'http://www.wikidata.org/entity/Q10960107',
#   'http://www.wikidata.org/entity/Q15354826',
#   'http://www.wikidata.org/entity/Q15232427',
#   'http://www.wikidata.org/entity/Q2602813',
#   'http://www.wikidata.org/entity/Q26228227',
#   'http://www.wikidata.org/entity/Q15232289',
#   'http://www.wikidata.org/entity/Q15246802',
#   'http://www.wikidata.org/entity/Q15476044',
#   'http://www.wikidata.org/entity/Q3228992',
#   'http://www.wikidata.org/entity/Q17580770',
#   'http://www.wikidata.org/entity/Q10891720',
#   'http://www.wikidata.org/entity/Q11083028',
#   'http://www.wikidata.org/entity/Q17581664',
#   'http://www.wikidata.org/entity/Q15392638',
#   'http://www.wikidata.org/entity/Q15552476',
#   'http://www.wikidata.org/entity/Q18077380',
#   'http://www.wikidata.org/entity/Q3337405',
#   'http://www.wikidata.org/entity/Q5137359',
#   'http://www.wikidata.org/entity/Q15384004',
#   'http://www.wikidata.org/entity/Q10898580',
#   'http://www.wikidata.org/entity/Q7535',
#   'http://www.wikidata.org/entity/Q15381462',
#   'http://www.wikidata.org/entity/Q15551658',
#   'http://www.wikidata.org/entity/Q164344',
#   'http://www.wikidata.org/entity/Q11086410',
#   'http://www.wikidata.org/entity/Q10536819',
#   'http://www.wikidata.org/entity/Q15232295',
#   'http://www.wikidata.org/entity/Q11075622',
#   'http://www.wikidata.org/entity/Q146136',
#   'http://www.wikidata.org/entity/Q15376934',
#   'http://www.wikidata.org/entity/Q10916972',
#   'http://www.wikidata.org/entity/Q15225143',
#   'http://www.wikidata.org/entity/Q1109580',
#   'http://www.wikidata.org/entity/Q1277255',
#   'http://www.wikidata.org/entity/Q18119727'],
#  'https://enpkg.commons-lab.org/kg/XRef': ['https://enpkg.commons-lab.org/module/chembl_activity_9735',
#   'https://enpkg.commons-lab.org/module/chembl_activity_994',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9179',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9795',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9826',
#   'https://enpkg.commons-lab.org/module/chembl_activity_99',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9877',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9599',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9885',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9891',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9653',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9730',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9846',
#   'https://enpkg.commons-lab.org/module/chembl_activity_985',
#   'https://enpkg.commons-lab.org/module/chembl_activity_998',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9986',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9435',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9928',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9736',
#   'https://enpkg.commons-lab.org/module/chembl_activity_97',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9985',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9993',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9922',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9840',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9979',
#   'https://enpkg.commons-lab.org/module/chembl_activity_982',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9754',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9943',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9835',
#   'https://enpkg.commons-lab.org/module/chembl_activity_871',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9866',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9987',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9667',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9970',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9991',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9821',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9981',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9731',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9302',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9823',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9869',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9742',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9995',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9959',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9747',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9929',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9105',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9908',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9703',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9881',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9936',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9421',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9938',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9992',
#   'https://enpkg.commons-lab.org/module/chembl_activity_960',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9832',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9901',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9969',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9707',
#   'https://enpkg.commons-lab.org/module/chembl_activity_8851',
#   'https://enpkg.commons-lab.org/module/chembl_activity_957',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9953',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9976',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9980',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9776',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9769',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9547',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9904',
#   'https://enpkg.commons-lab.org/module/chembl_activity_993',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9892',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9915',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9437',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9779',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9923',
#   'https://enpkg.commons-lab.org/module/chembl_activity_958',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9824',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9851',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9743',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9999',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9292',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9920',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9961',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9856',
#   'https://enpkg.commons-lab.org/module/chembl_activity_8913',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9681',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9949',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9960',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9400',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9954',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9998',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9825',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9679',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9942',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9935',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9166',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9895',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9809',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9861',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9805',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL916938'],
#  'https://enpkg.commons-lab.org/kg/LFpair': ['https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:96_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:787',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:883_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:3275',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:945_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:2690',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:961_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:1475',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:830_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:1985',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:990_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:328',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:849_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:1610',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:953_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:2052',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:93_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:1881',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:731_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:229',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:978_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:64',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:776_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:2135',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:982_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:453',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:899_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:2441',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:820_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:1692',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:996_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:3111',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:86_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:1738',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:937_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:3',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:9_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:41',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:816_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:2010',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:950_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:257',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:95_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:3064',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:98_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:21',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:967_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:1810',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:953_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:1798',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:93_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:2042',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:945_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:784',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:960_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:2838',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:758_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:687',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:94_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:185',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:999_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:321',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:990_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:15',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:877_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:2042',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:972_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:1993',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:921_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:2643',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:951_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:1726',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:939_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:933',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:801_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:844',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:89_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:575',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:92_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:1861',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:956_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:2181',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:999_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:169',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:885_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:647',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:991_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:1602',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:873_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:3048',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:921_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:1003',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:991_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:2310',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:824_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:1810',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:97_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:2167',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:905_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:1234',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:976_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:2540',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:979_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:942',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:744_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:122',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:972_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:1183',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:874_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:629',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:992_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:692',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:869_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:1682',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:98_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:3215',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:996_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:2750',
#   'https://enpkg.commons-lab.org/kg/lcms_feature_pair_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:886_mzspec:MSV000088521:SC_AP_Wi_DCM_features_ms2_pos.mgf:scan:1023',
# ...
#   'https://enpkg.commons-lab.org/module/chembl_activity_8951',
#   'https://enpkg.commons-lab.org/module/chembl_activity_985',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9855',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9546',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9708',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9756',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9915',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9912',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9428',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9697',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9873',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9906',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9561',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9801',
#   'https://enpkg.commons-lab.org/module/chembl_activity_996',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9820',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9135',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9792',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9692',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9928',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9681',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9760',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9776',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9787',
#   'https://enpkg.commons-lab.org/module/chembl_activity_966',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9931',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9440',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9895',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9818',
#   'https://enpkg.commons-lab.org/module/chembl_activity_9744'],
#  'https://enpkg.commons-lab.org/module/ChEMBLAssay': ['https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL4052230',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL712541',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL3993392',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL4400859',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL4257690',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL1653367',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL916927',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL4310394',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL819835',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL4049077',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL4049058',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL4313870',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL1046937',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL3431451',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL4614123',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL3269865',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL4047222',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL4614124',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL1660761',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL1273014',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL4408999',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL1072442',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL917490',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL3993413',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL4313852',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL4305603',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL2401085',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL4409040',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL4231808',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL4409003',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL807760',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL4408973',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL1033974',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL4052282',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL3583602',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL4180000',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL4039147',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL4409021',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL4221288',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL3794889',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL4338321',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL3135368',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL4052229',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL4409039',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL1666859',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL3124636',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL3993396',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL3254562',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL3614976',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL4039149',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL917493',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL811870',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL4310422',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL3757644',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL3803282',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL4369851',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL2399117',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL4221311',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL3431452',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL916922',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL1666987',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL4408977',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL4343792',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL3256799',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL4263547',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL1047658',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL3254564',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL916932',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL929660',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL943740',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL3993428',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL916934',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL4393892',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL4408975',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL3265910',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL916935',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL920742',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL4235932',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL4221300',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL709441',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL4345844',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL2444551',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL4408995',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL3376539',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL3789241',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL918377',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL811869',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL918376',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL4023887',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL4345845',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL712536',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL4613047',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL3265913',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL1661625',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL4408976',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL4621674',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL3614977',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL4310398',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL2175271',
#   'https://www.ebi.ac.uk/chembl/assay_report_card/CHEMBL916939'],
#  'https://enpkg.commons-lab.org/module/ChEMBLDocument': ['https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL1149817',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL1154711',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL1208769',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL2331458',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL3763111',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL2439952',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL1147196',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL1131382',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL3259603',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL1154850',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL1155571',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL4177714',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL3352271',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL4680199',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL4342474',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL2417491',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL4425181',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL1158974',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL1795266',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL1151435',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL2390909',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL1773052',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL3769347',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL2407047',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL1149661',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL1139083',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL1240432',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL1152566',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL1135645',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL3872246',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL3046674',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL4043299',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL3856184',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL3585262',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL1128838',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL1926546',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL3576854',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL1157633',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL1781904',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL1157662',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL1773047',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL1157129',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL4422697',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL1149610',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL2046271',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL1136884',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL1151193',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL1149446',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL3627660',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL1139263',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL3826916',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL4610124',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL2412993',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL4325912',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL2417546',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL4038265',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL3243940',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL1641541',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL1152725',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL1144459',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL2417423',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL4368882',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL3774329',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL1136916',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL4627311',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL2311501',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL3352665',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL1149200',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL4118256',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL3228036',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL3600370',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL1156161',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL4184091',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL1134692',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL3992522',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL1649109',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL1154680',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL1933052',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL4052705',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL1153871',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL1141653',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL2434884',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL3813611',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL3112401',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL3588854',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL4765358',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL3751714',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL1681663',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL1165910',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL2069191',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL1150856',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL1275590',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL3244185',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL1155062',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL3414460',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL4052627',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL4732090',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL1142632',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL4428031',
#   'https://www.ebi.ac.uk/chembl/document_report_card/CHEMBL4402577'],
#  'http://xmlns.com/foaf/0.1/Person': ['http://orcid.org/0000-0003-3389-2191',
#   'http://orcid.org/0000-0002-9619-1707',
#   'http://orcid.org/0000-0002-3648-7362',
#   'http://orcid.org/0000-0001-9292-9463'],
#  'http://www.w3.org/2002/07/owl#Ontology': ['file:///var/vhosts/commons-lab.org/enpkg/enpkg_website_PROD.git/common/data/config/schema/enpkg_schema.ttl'],
#  'http://purl.org/dc/dcmitype/Dataset': ['https://enpkg.commons-lab.org/kg/EVERYTHING.1',
#   'https://enpkg.commons-lab.org/kg/EVERYTHING']}

# %% [markdown]
# ## Step 3: get all predicates for each instance

# %%
query3 = """  
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX enpkg: <https://enpkg.commons-lab.org/kg/>
select distinct ?p where {{ 
	{{<{inst}> ?p ?x .}}
    UNION
    {{?y ?p <{inst}> .}}
}} 
"""

# %%
all_preds = set()
class_preds = {}
for c in random_instances:
    class_preds[c] = set()
    for enum, i in enumerate(set(random_instances[c])):
        pred_output =  run_sparql(query3.format(inst = i))
        set_pred_output = set(x['p']['value'] for x in pred_output)
        class_preds[c] = class_preds[c].union(set_pred_output)
        all_preds = all_preds.union(set_pred_output)
    print(c, len(class_preds[c]), len(all_preds))
# Out:
# http://www.w3.org/1999/02/22-rdf-syntax-ns#Property 10 10
# http://www.w3.org/2002/07/owl#TransitiveProperty 6 11
# http://www.w3.org/2002/07/owl#SymmetricProperty 4 11
# http://www.w3.org/1999/02/22-rdf-syntax-ns#List 1 11
# http://www.w3.org/2000/01/rdf-schema#Class 6 12
# http://www.w3.org/2000/01/rdf-schema#Datatype 2 12
# http://www.w3.org/2000/01/rdf-schema#ContainerMembershipProperty 1 12
# https://enpkg.commons-lab.org/kg/RawMaterial 11 22
# https://enpkg.commons-lab.org/kg/LabObject 15 26
# http://rdfs.org/ns/void#Dataset 8 33
# https://enpkg.commons-lab.org/kg/LabExtract 7 33
# https://enpkg.commons-lab.org/kg/WDTaxon 4 34
# https://enpkg.commons-lab.org/kg/XRef 11 43
# https://enpkg.commons-lab.org/kg/LFpair 7 49
# https://enpkg.commons-lab.org/kg/SpectralPair 7 49
# https://enpkg.commons-lab.org/kg/LCMSFeature 23 66
# https://enpkg.commons-lab.org/kg/MS2Spectrum 23 66
# https://enpkg.commons-lab.org/kg/WDChemical 2 66
# https://enpkg.commons-lab.org/kg/InChIkey2D 2 67
# https://enpkg.commons-lab.org/kg/NPCClass 3 69
# https://enpkg.commons-lab.org/kg/NPCSuperclass 7 73
# https://enpkg.commons-lab.org/kg/NPCPathway 7 73
# https://enpkg.commons-lab.org/kg/ChemicalTaxonomy 5 73
# https://enpkg.commons-lab.org/kg/InChIkey 6 75
# https://enpkg.commons-lab.org/kg/ChemicalEntity 6 75
# https://enpkg.commons-lab.org/kg/LCMSAnalysisPos 10 80
# https://enpkg.commons-lab.org/kg/LCMSAnalysis 12 81
# https://enpkg.commons-lab.org/kg/LCMSFeatureList 7 81
# https://enpkg.commons-lab.org/kg/SiriusCanopusAnnotation 9 84
# https://enpkg.commons-lab.org/kg/Annotation 10 90
# https://enpkg.commons-lab.org/kg/Spec2VecDoc 5 92
# https://enpkg.commons-lab.org/kg/spec2vec 5 92
# https://enpkg.commons-lab.org/kg/IsdbAnnotation 10 92
# https://enpkg.commons-lab.org/kg/SiriusStructureAnnotation 10 96
# https://enpkg.commons-lab.org/kg/Spec2VecLoss 4 97
# https://enpkg.commons-lab.org/kg/Spec2VecPeak 4 97
# https://enpkg.commons-lab.org/kg/LCMSAnalysisNeg 9 97
# https://enpkg.commons-lab.org/module/L610ugml 4 98
# https://enpkg.commons-lab.org/kg/BioAssayResults 5 98
# https://enpkg.commons-lab.org/module/SwissTPHBioAssay 5 98
# https://enpkg.commons-lab.org/module/Ldono10ugml 5 98
# https://enpkg.commons-lab.org/module/Ldono2ugml 5 98
# https://enpkg.commons-lab.org/module/Tbrucei10ugml 5 98
# https://enpkg.commons-lab.org/module/Tbrucei2ugml 5 98
# https://enpkg.commons-lab.org/module/Tcruzi10ugml 5 98
# https://enpkg.commons-lab.org/module/ChEMBLTarget 3 98
# https://enpkg.commons-lab.org/kg/LabBlank 3 98
# https://enpkg.commons-lab.org/kg/LabQc 3 98
# https://enpkg.commons-lab.org/module/ChEMBLChemical 3 98
# https://enpkg.commons-lab.org/module/ChEMBLAssayResults 11 98
# https://enpkg.commons-lab.org/module/ChEMBLAssay 2 98
# https://enpkg.commons-lab.org/module/ChEMBLDocument 3 99
# http://xmlns.com/foaf/0.1/Person 6 104
# http://www.w3.org/2002/07/owl#Ontology 11 112
# http://purl.org/dc/dcmitype/Dataset 7 117

# %%
class_preds = {key:list(value) for key,value in class_preds.items()}

# %%
# Write json file with all predicates sorted by class
with open(directory+'/predicates.json', 'w') as file:
    # Write the dictionary to the file as JSON
    json.dump(class_preds, file)

# %%
# Write txt file of all distinct predicates
with open(directory+'/predicates.txt', 'w') as file:
    # Iterate over each element in the list
    for element in all_preds:
        # Write the element to the file
        file.write(str(element) + '\n')

# %% [markdown]
# # Get subject predicate object triples for each predicate
#
# ### Load predicates

# %%
filename = directory + '/predicates.txt'
with open(filename, 'r') as file:
    lines = file.readlines()
    
preds = [line.strip() for line in lines]

# %%
query_triples = """  
CONSTRUCT {{?s_class <{pred}> ?o_class}} WHERE {{
SELECT DISTINCT ?s_class ?o_class WHERE {{
  # ?s <{pred}> ?o .
  OPTIONAL {{ ?s a ?s_class . }}
  OPTIONAL {{ ?o a ?o_type . }}
  BIND(IF(bound(?o_type), ?o_type, IF(isLiteral(?o), datatype(?o),"")) AS ?o_class)
    }}
}}
"""

os.mkdir(directory+'/schema_ttl/')
filename_template = directory + """/schema_ttl/{pred}.ttl"""

def remove_prefix(uri, prefix='https://enpkg.commons-lab.org/'):
    return uri.split('/')[-1]

# %%
# Construct schema for each predicate 

for i, pred in enumerate(preds):
    pred_only = remove_prefix(pred)
    print('Starting', pred_only)

    start_time = time.time()  # Start time of the current iteration
    results = run_sparql_construct(query_triples.format(pred=pred), filename_template.format(pred=pred_only))

    end_time = time.time()  # End time of the current iteration
    duration = end_time - start_time  # Duration of the current iteration

    print('Finished', pred_only, 'in', duration, 'seconds')

    if i % 10 == 0:
        print('Cycle number:', i)
# Out:
# Starting has_member_2
# Finished has_member_2 in 77.21234893798828 seconds
# Starting has_usi
# Finished has_usi in 28.674247980117798 seconds
# Cycle number: 50
# Starting creator
# Finished creator in 0.01198720932006836 seconds
# Starting preferredNamespaceUri
# Finished preferredNamespaceUri in 0.013447046279907227 seconds
# Starting activity_value
# Finished activity_value in 1.0114738941192627 seconds
# Starting has_consistency_score
# Finished has_consistency_score in 3.777876853942871 seconds
# Starting has_broad_organe
# Finished has_broad_organe in 0.02123284339904785 seconds
# Starting has_npc_class
# Finished has_npc_class in 2.302672863006592 seconds
# Starting has_canopus_annotation
# Finished has_canopus_annotation in 8.891426086425781 seconds
# Starting has_parent_mass
# Finished has_parent_mass in 10.720993995666504 seconds
# Starting rdf-schema#subClassOf
# Finished rdf-schema#subClassOf in 0.007171154022216797 seconds
# Starting assay_id
# Finished assay_id in 0.5656979084014893 seconds
# Cycle number: 60
# Starting has_massive_doi
# Finished has_massive_doi in 0.042958974838256836 seconds
# Starting has_lab_process
# Finished has_lab_process in 0.027456045150756836 seconds
# Starting description
# Finished description in 0.007231950759887695 seconds
# Starting has_canopus_npc_class
# Finished has_canopus_npc_class in 9.320958137512207 seconds
# Starting has_cosine
# Finished has_cosine in 38.684898853302 seconds
# Starting activity_unit
# Finished activity_unit in 0.5183742046356201 seconds
# Starting has_retention_time
# Finished has_retention_time in 10.510074138641357 seconds
# Starting has_smiles
# Finished has_smiles in 2.220402956008911 seconds
# Starting has_isdb_annotation
# Finished has_isdb_annotation in 4.969031095504761 seconds
# Starting has_member
# Finished has_member in 73.9569799900055 seconds
# Cycle number: 70
# Starting gnps_component_link
# Finished gnps_component_link in 3.3774361610412598 seconds
# Starting has_sirius_annotation
# Finished has_sirius_annotation in 20.83372688293457 seconds
# Starting has_sirius_score
# Finished has_sirius_score in 7.381033897399902 seconds
# Starting stated_in_document
# Finished stated_in_document in 0.6097769737243652 seconds
# Starting preferredNamespacePrefix
# Finished preferredNamespacePrefix in 0.007897138595581055 seconds
# Starting owl#versionInfo
# Finished owl#versionInfo in 0.006898164749145508 seconds
# Starting rdf-schema#range
# Finished rdf-schema#range in 0.006499767303466797 seconds
# Starting owl#versionIRI
# Finished owl#versionIRI in 0.006066322326660156 seconds
# Starting has_subsystem
# Finished has_subsystem in 0.018895864486694336 seconds
# Starting rdf-schema#subPropertyOf
# Finished rdf-schema#subPropertyOf in 0.0071408748626708984 seconds
# Cycle number: 80
# Starting has_lcms_feature
# Finished has_lcms_feature in 7.0053651332855225 seconds
# Starting has_canopus_npc_class_prob
# Finished has_canopus_npc_class_prob in 8.208884954452515 seconds
# Starting has_chembl_activity
# Finished has_chembl_activity in 0.6136081218719482 seconds
# Starting owl#inverseOf
# Finished owl#inverseOf in 0.007222890853881836 seconds
# Starting target_name
# Finished target_name in 0.49678802490234375 seconds
# Starting has_lcms_feature_list
# Finished has_lcms_feature_list in 0.04254007339477539 seconds
# Starting has_canopus_npc_pathway_prob
# Finished has_canopus_npc_pathway_prob in 8.08707308769226 seconds
# Starting has_organe
# Finished has_organe in 0.021259069442749023 seconds
# Starting has_gnpslcms_link
# Finished has_gnpslcms_link in 0.03247189521789551 seconds

# %% [markdown]
# ### Fix prefix conflicts and merge ttl files

# %%
prefix_map = {'http://schema.org/':'schema',
              'https://enpkg.commons-lab.org/module/':'enpkg_module',
              'http://purl.org/pav/':'pav',
              'http://example.org/':'example',
              'https://enpkg.commons-lab.org/kg/':'enpkg'}


# Iterate over each Turtle file
for filename in glob.glob('./schema_ttl/*.ttl'):
    g = Graph()
    g.parse(filename, format='turtle')

    # Update prefix definitions
    for namespace, prefix in prefix_map.items():
        g.bind(prefix, namespace)

    # Save the graph
    g.serialize(destination=filename, format='turtle')

g = Graph()

# Load all ttl files in the folder
for filename in glob.glob('./schema_ttl/*.ttl'):
    g.parse(filename, format='turtle')

# Save the merged graph
g.serialize(destination=directory+'/merged.ttl', format='turtle')
# Out:
# <Graph identifier=Nd87c33f08ff245c1bdeefff8b7140c97 (<class 'rdflib.graph.Graph'>)>

# %%
# Load the TTL file
ttl_file = 'schema_ttl/merged.ttl'
with open(ttl_file, 'r') as file:
    content = file.read()

# Initialize Tiktoken with the desired encoding model
encoding = tiktoken.encoding_for_model("gpt-4")

# Count the number of tokens in the TTL file
token_count = len(encoding.encode(content))

print(f"The TTL file '{ttl_file}' contains {token_count} tokens.")
# Out:
# The TTL file 'schema_local_ttl/merged.ttl' contains 4384 tokens.
