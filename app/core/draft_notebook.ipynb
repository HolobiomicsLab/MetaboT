# %%
import csv
import tempfile

def json_to_csv(result):
    # Create a temporary CSV file
    with tempfile.NamedTemporaryFile(delete=False, mode='w', suffix='.csv', newline='') as temp_file:
        # Create a CSV writer object
        csv_writer = csv.writer(temp_file)
        
        # Check if 'results' and 'bindings' exist to avoid KeyError
        if "results" in result and "bindings" in result["results"]:
            # Extract the first row to get the headers (column names)
            headers = result["results"]["bindings"][0].keys()
            csv_writer.writerow(headers)
            
            # Write data rows
            for binding in result["results"]["bindings"]:
                row = [binding.get(column, {}).get("value", "") for column in headers]
                csv_writer.writerow(row)
        
        # Store the path for use in the return value
        temp_file_path = temp_file.name
        return temp_file_path

# %%
print(json_to_csv(result))
# Out:
# /var/folders/20/4kgcw5656h12ss_nj18mndwm0000gn/T/tmpur33iao0.csv

# %%
@staticmethod
    def json_to_csv(result):
    # Create a temporary CSV file
        with tempfile.NamedTemporaryFile(delete=False, mode='w', suffix='.csv', newline='') as temp_file:
        # Create a CSV writer object
            csv_writer = csv.writer(temp_file)
        
        # Check if 'results' and 'bindings' exist to avoid KeyError
            if "results" in result and "bindings" in result["results"]:
            # Extract the first row to get the headers (column names)
                headers = result["results"]["bindings"][0].keys()
                csv_writer.writerow(headers)
            
            # Write data rows
                for binding in result["results"]["bindings"]:
                    row = [binding.get(column, {}).get("value", "") for column in headers]
                    csv_writer.writerow(row)
        
            # Store the path for use in the return value
            temp_file_path = temp_file.name
            return temp_file_path

# %%
print(result)
# Out:
# {'head': {'vars': ['featurePos', 'retentionTimePos', 'InChIKey2DPos', 'featureNeg', 'retentionTimeNeg', 'InChIKey2DNeg']}, 'results': {'bindings': [{'featurePos': {'type': 'uri', 'value': 'https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:464'}, 'retentionTimePos': {'datatype': 'http://www.w3.org/2001/XMLSchema#float', 'type': 'literal', 'value': '1.2292333333333334'}, 'InChIKey2DPos': {'type': 'uri', 'value': 'https://enpkg.commons-lab.org/kg/HOEVRHHMDJKUMZ'}, 'featureNeg': {'type': 'uri', 'value': 'https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:84'}, 'retentionTimeNeg': {'datatype': 'http://www.w3.org/2001/XMLSchema#float', 'type': 'literal', 'value': '1.58195'}, 'InChIKey2DNeg': {'type': 'uri', 'value': 'https://enpkg.commons-lab.org/kg/HOEVRHHMDJKUMZ'}}, {'featurePos': {'type': 'uri', 'value': 'https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_fe
# ...

# %%
#creating csv temp file inside the _call 
 with tempfile.NamedTemporaryFile(
            delete=False, mode="w", suffix=".csv", newline=""
        ) as temp_file:
            # Create a CSV writer object
            csv_writer = csv.writer(temp_file)

            # Assuming your result structure contains rows of data under 'results' key
            # Check if 'results' and 'bindings' exist to avoid KeyError
            if "results" in result and "bindings" in result["results"]:
                # Extract the first row to get the headers (column names)
                headers = result["results"]["bindings"][0].keys()
                csv_writer.writerow(headers)

                # Write data rows
                for binding in result["results"]["bindings"]:
                    row = [
                        binding.get(column, {}).get("value", "") for column in headers
                    ]
                    csv_writer.writerow(row)

            # Store the path for use in the return value
            temp_file_path = temp_file.name
            print("Saving results to file: ", temp_file_path)
# counting the tokens in the question
        # question_tokens = RdfGraph.token_counter(prompt)
        # # counting the tokens in the result/sparql output
        # result_tokens = RdfGraph.token_counter(result)
        # # counting the tokens in the sparql query
        # sparql_tokens = RdfGraph.token_counter(generated_sparql)
        # # contextualized_result = {'query': generated_sparql, 'result': result}
        # # Saving the result to a temporary file
        
        
        # Step 3: If total exceeds the limit, read the content from a CSV file
        # if total_tokens > 8100:
        #     # Make sure 'filepath' is defined and points to your CSV file
        #     result = pd.read_csv(temp_file_path)
        # # Building the result dictionary

# %%
print(path)
# Out:
# /var/folders/20/4kgcw5656h12ss_nj18mndwm0000gn/T/tmp_6ir4c1g.csv

# %%
#creating temp file in json format
        with tempfile.NamedTemporaryFile(delete=False, mode='w', suffix='.json') as temp_file:
       
        # Here we're saving only the 'result' part
             json.dump(result, temp_file, ensure_ascii=False)
             temp_file_path = temp_file.name  # Store the path for use in the return value

# %%
result=[{
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:464",
      "retentionTimePos": "1.2292333333333334",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/HOEVRHHMDJKUMZ",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:84",
      "retentionTimeNeg": "1.58195",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/HOEVRHHMDJKUMZ"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:85",
      "retentionTimePos": "1.5790666666666666",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/HOEVRHHMDJKUMZ",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:84",
      "retentionTimeNeg": "1.58195",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/HOEVRHHMDJKUMZ"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:240",
      "retentionTimePos": "2.952316666666667",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/PTQQIYXPVOPTSV",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:243",
      "retentionTimeNeg": "2.9496333333333333",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/PTQQIYXPVOPTSV"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:410",
      "retentionTimePos": "4.44905",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ANSWFKILBODRES",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:253",
      "retentionTimeNeg": "4.052933333333333",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ANSWFKILBODRES"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:84",
      "retentionTimePos": "2.5797166666666667",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/DQLOCJPJWKCPOE",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:11",
      "retentionTimeNeg": "3.1107500000000003",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/DQLOCJPJWKCPOE"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:84",
      "retentionTimePos": "2.5797166666666667",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/DQLOCJPJWKCPOE",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:248",
      "retentionTimeNeg": "3.94995",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/DQLOCJPJWKCPOE"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:84",
      "retentionTimePos": "2.5797166666666667",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/DQLOCJPJWKCPOE",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:48",
      "retentionTimeNeg": "3.3402666666666665",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/DQLOCJPJWKCPOE"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:84",
      "retentionTimePos": "2.5797166666666667",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/DQLOCJPJWKCPOE",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:85",
      "retentionTimeNeg": "3.6826",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/DQLOCJPJWKCPOE"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:84",
      "retentionTimePos": "2.5797166666666667",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/DQLOCJPJWKCPOE",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:147",
      "retentionTimeNeg": "2.458916666666666",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/DQLOCJPJWKCPOE"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:84",
      "retentionTimePos": "2.5797166666666667",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/DQLOCJPJWKCPOE",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:215",
      "retentionTimeNeg": "2.585033333333333",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/DQLOCJPJWKCPOE"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:130",
      "retentionTimePos": "2.3292333333333333",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/XGADTAYOFHOFIW",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:116",
      "retentionTimeNeg": "2.2449166666666667",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/XGADTAYOFHOFIW"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:130",
      "retentionTimePos": "2.3292333333333333",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/XGADTAYOFHOFIW",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:6",
      "retentionTimeNeg": "2.328966666666666",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/XGADTAYOFHOFIW"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:143",
      "retentionTimePos": "4.5575",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:164",
      "retentionTimeNeg": "3.690116666666667",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:143",
      "retentionTimePos": "4.5575",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:172",
      "retentionTimeNeg": "4.411600000000001",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:143",
      "retentionTimePos": "4.5575",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:226",
      "retentionTimeNeg": "4.6238166666666665",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:132",
      "retentionTimePos": "4.621833333333333",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:164",
      "retentionTimeNeg": "3.690116666666667",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:132",
      "retentionTimePos": "4.621833333333333",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:172",
      "retentionTimeNeg": "4.411600000000001",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:132",
      "retentionTimePos": "4.621833333333333",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:226",
      "retentionTimeNeg": "4.6238166666666665",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:364",
      "retentionTimePos": "1.7661",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/DKZBBWMURDFHNE",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:143",
      "retentionTimeNeg": "1.76635",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/DKZBBWMURDFHNE"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:179",
      "retentionTimePos": "6.401",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/RCRIEGZGQYGDDM",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:108",
      "retentionTimeNeg": "6.58255",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/RCRIEGZGQYGDDM"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:179",
      "retentionTimePos": "6.401",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/RCRIEGZGQYGDDM",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:9",
      "retentionTimeNeg": "6.409166666666667",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/RCRIEGZGQYGDDM"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:535",
      "retentionTimePos": "6.578833333333334",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/RCRIEGZGQYGDDM",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:108",
      "retentionTimeNeg": "6.58255",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/RCRIEGZGQYGDDM"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:535",
      "retentionTimePos": "6.578833333333334",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/RCRIEGZGQYGDDM",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:9",
      "retentionTimeNeg": "6.409166666666667",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/RCRIEGZGQYGDDM"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:225",
      "retentionTimePos": "5.000966666666667",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/LUZSWWYKKLTDHU",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:62",
      "retentionTimeNeg": "4.9133",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/LUZSWWYKKLTDHU"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:186",
      "retentionTimePos": "5.046933333333333",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/LUZSWWYKKLTDHU",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:62",
      "retentionTimeNeg": "4.9133",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/LUZSWWYKKLTDHU"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:23",
      "retentionTimePos": "4.836416666666667",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/LUZSWWYKKLTDHU",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:62",
      "retentionTimeNeg": "4.9133",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/LUZSWWYKKLTDHU"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:266",
      "retentionTimePos": "4.052433333333333",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/RCMABBHQYMBYKV",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:155",
      "retentionTimeNeg": "4.052933333333333",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/RCMABBHQYMBYKV"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:266",
      "retentionTimePos": "4.052433333333333",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/RCMABBHQYMBYKV",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:55",
      "retentionTimeNeg": "3.563283333333333",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/RCMABBHQYMBYKV"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:266",
      "retentionTimePos": "4.052433333333333",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/RCMABBHQYMBYKV",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:148",
      "retentionTimeNeg": "4.44895",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/RCMABBHQYMBYKV"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:287",
      "retentionTimePos": "2.885383333333333",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/JHXAZBBVQSRKJR",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:24",
      "retentionTimeNeg": "4.8358333333333325",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/JHXAZBBVQSRKJR"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:287",
      "retentionTimePos": "2.885383333333333",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/JHXAZBBVQSRKJR",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:14",
      "retentionTimeNeg": "4.73675",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/JHXAZBBVQSRKJR"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:287",
      "retentionTimePos": "2.885383333333333",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/JHXAZBBVQSRKJR",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:29",
      "retentionTimeNeg": "4.68605",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/JHXAZBBVQSRKJR"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:39",
      "retentionTimePos": "4.920116666666667",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/LUZSWWYKKLTDHU",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:62",
      "retentionTimeNeg": "4.9133",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/LUZSWWYKKLTDHU"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:139",
      "retentionTimePos": "3.56325",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:164",
      "retentionTimeNeg": "3.690116666666667",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:139",
      "retentionTimePos": "3.56325",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:172",
      "retentionTimeNeg": "4.411600000000001",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:139",
      "retentionTimePos": "3.56325",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:226",
      "retentionTimeNeg": "4.6238166666666665",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:187",
      "retentionTimePos": "3.6476166666666665",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:164",
      "retentionTimeNeg": "3.690116666666667",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:187",
      "retentionTimePos": "3.6476166666666665",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:172",
      "retentionTimeNeg": "4.411600000000001",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:187",
      "retentionTimePos": "3.6476166666666665",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:226",
      "retentionTimeNeg": "4.6238166666666665",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:552",
      "retentionTimePos": "3.181666666666666",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/RCMABBHQYMBYKV",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:155",
      "retentionTimeNeg": "4.052933333333333",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/RCMABBHQYMBYKV"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:552",
      "retentionTimePos": "3.181666666666666",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/RCMABBHQYMBYKV",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:55",
      "retentionTimeNeg": "3.563283333333333",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/RCMABBHQYMBYKV"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:552",
      "retentionTimePos": "3.181666666666666",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/RCMABBHQYMBYKV",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:148",
      "retentionTimeNeg": "4.44895",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/RCMABBHQYMBYKV"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:799",
      "retentionTimePos": "2.9305000000000003",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/NFABMCCMPXXBFY",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:177",
      "retentionTimeNeg": "3.5550833333333336",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/NFABMCCMPXXBFY"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:386",
      "retentionTimePos": "3.4682000000000004",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/PQPRTPXWQQQKJC",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:86",
      "retentionTimeNeg": "3.46975",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/PQPRTPXWQQQKJC"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:259",
      "retentionTimePos": "6.892",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/UQFZKTIHSICSPG",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:290",
      "retentionTimeNeg": "7.363133333333334",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/UQFZKTIHSICSPG"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:770",
      "retentionTimePos": "6.995500000000001",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/UQFZKTIHSICSPG",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:290",
      "retentionTimeNeg": "7.363133333333334",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/UQFZKTIHSICSPG"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:835",
      "retentionTimePos": "6.013733333333334",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/UQFZKTIHSICSPG",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:290",
      "retentionTimeNeg": "7.363133333333334",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/UQFZKTIHSICSPG"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:28",
      "retentionTimePos": "4.739116666666666",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/JHXAZBBVQSRKJR",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:24",
      "retentionTimeNeg": "4.8358333333333325",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/JHXAZBBVQSRKJR"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:28",
      "retentionTimePos": "4.739116666666666",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/JHXAZBBVQSRKJR",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:14",
      "retentionTimeNeg": "4.73675",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/JHXAZBBVQSRKJR"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:28",
      "retentionTimePos": "4.739116666666666",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/JHXAZBBVQSRKJR",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:29",
      "retentionTimeNeg": "4.68605",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/JHXAZBBVQSRKJR"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:298",
      "retentionTimePos": "2.4112666666666667",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/CNKGXSBPJQHCKK",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:15",
      "retentionTimeNeg": "2.41945",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/CNKGXSBPJQHCKK"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:344",
      "retentionTimePos": "1.26885",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/HAVWRBANWNTOJX",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:119",
      "retentionTimeNeg": "1.27065",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/HAVWRBANWNTOJX"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:9",
      "retentionTimePos": "2.3292333333333333",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/XGADTAYOFHOFIW",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:116",
      "retentionTimeNeg": "2.2449166666666667",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/XGADTAYOFHOFIW"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:9",
      "retentionTimePos": "2.3292333333333333",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/XGADTAYOFHOFIW",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:6",
      "retentionTimeNeg": "2.328966666666666",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/XGADTAYOFHOFIW"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:331",
      "retentionTimePos": "4.052433333333333",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:164",
      "retentionTimeNeg": "3.690116666666667",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:331",
      "retentionTimePos": "4.052433333333333",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:172",
      "retentionTimeNeg": "4.411600000000001",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:331",
      "retentionTimePos": "4.052433333333333",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:226",
      "retentionTimeNeg": "4.6238166666666665",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:401",
      "retentionTimePos": "3.4682000000000004",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/RFHOXTWWHVRIKG",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:198",
      "retentionTimeNeg": "3.46975",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/RFHOXTWWHVRIKG"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:728",
      "retentionTimePos": "4.096233333333333",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/WMIKDZKELUVXGM",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:277",
      "retentionTimeNeg": "3.7508166666666662",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/WMIKDZKELUVXGM"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:616",
      "retentionTimePos": "1.089",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/CRSFLLTWRCYNNX",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:165",
      "retentionTimeNeg": "1.0961833333333333",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/CRSFLLTWRCYNNX"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:48",
      "retentionTimePos": "3.3383166666666666",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/DQLOCJPJWKCPOE",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:11",
      "retentionTimeNeg": "3.1107500000000003",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/DQLOCJPJWKCPOE"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:48",
      "retentionTimePos": "3.3383166666666666",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/DQLOCJPJWKCPOE",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:248",
      "retentionTimeNeg": "3.94995",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/DQLOCJPJWKCPOE"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:48",
      "retentionTimePos": "3.3383166666666666",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/DQLOCJPJWKCPOE",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:48",
      "retentionTimeNeg": "3.3402666666666665",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/DQLOCJPJWKCPOE"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:48",
      "retentionTimePos": "3.3383166666666666",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/DQLOCJPJWKCPOE",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:85",
      "retentionTimeNeg": "3.6826",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/DQLOCJPJWKCPOE"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:48",
      "retentionTimePos": "3.3383166666666666",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/DQLOCJPJWKCPOE",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:147",
      "retentionTimeNeg": "2.458916666666666",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/DQLOCJPJWKCPOE"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:48",
      "retentionTimePos": "3.3383166666666666",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/DQLOCJPJWKCPOE",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:215",
      "retentionTimeNeg": "2.585033333333333",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/DQLOCJPJWKCPOE"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:439",
      "retentionTimePos": "3.3383166666666666",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/PLYCKVKDTOBZTL",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:12",
      "retentionTimeNeg": "3.3402666666666665",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/PLYCKVKDTOBZTL"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:439",
      "retentionTimePos": "3.3383166666666666",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/PLYCKVKDTOBZTL",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:26",
      "retentionTimeNeg": "3.59575",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/PLYCKVKDTOBZTL"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:722",
      "retentionTimePos": "3.1199166666666667",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/RCMABBHQYMBYKV",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:155",
      "retentionTimeNeg": "4.052933333333333",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/RCMABBHQYMBYKV"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:722",
      "retentionTimePos": "3.1199166666666667",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/RCMABBHQYMBYKV",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:55",
      "retentionTimeNeg": "3.563283333333333",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/RCMABBHQYMBYKV"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:722",
      "retentionTimePos": "3.1199166666666667",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/RCMABBHQYMBYKV",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:148",
      "retentionTimeNeg": "4.44895",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/RCMABBHQYMBYKV"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:181",
      "retentionTimePos": "2.885383333333333",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/MDIUMSLCYIJBQC",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:109",
      "retentionTimeNeg": "3.3334",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/MDIUMSLCYIJBQC"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:181",
      "retentionTimePos": "2.885383333333333",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/MDIUMSLCYIJBQC",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:59",
      "retentionTimeNeg": "3.12655",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/MDIUMSLCYIJBQC"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:181",
      "retentionTimePos": "2.885383333333333",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/MDIUMSLCYIJBQC",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:64",
      "retentionTimeNeg": "3.177633333333333",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/MDIUMSLCYIJBQC"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:181",
      "retentionTimePos": "2.885383333333333",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/MDIUMSLCYIJBQC",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:19",
      "retentionTimeNeg": "2.8838166666666667",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/MDIUMSLCYIJBQC"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:267",
      "retentionTimePos": "4.456033333333334",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:164",
      "retentionTimeNeg": "3.690116666666667",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:267",
      "retentionTimePos": "4.456033333333334",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:172",
      "retentionTimeNeg": "4.411600000000001",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:267",
      "retentionTimePos": "4.456033333333334",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:226",
      "retentionTimeNeg": "4.6238166666666665",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:405",
      "retentionTimePos": "1.7512166666666666",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/HHXMOTDTSDYYEI",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:103",
      "retentionTimeNeg": "2.068383333333333",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/HHXMOTDTSDYYEI"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:405",
      "retentionTimePos": "1.7512166666666666",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/HHXMOTDTSDYYEI",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:146",
      "retentionTimeNeg": "1.89865",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/HHXMOTDTSDYYEI"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:406",
      "retentionTimePos": "5.721566666666666",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/OWRZLPFARZIZOG",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:138",
      "retentionTimeNeg": "4.68605",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/OWRZLPFARZIZOG"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:406",
      "retentionTimePos": "5.721566666666666",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/OWRZLPFARZIZOG",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:129",
      "retentionTimeNeg": "4.752466666666667",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/OWRZLPFARZIZOG"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:606",
      "retentionTimePos": "6.644283333333333",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/OFFZRQDMDYSGMV",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:22",
      "retentionTimeNeg": "6.895216666666667",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/OFFZRQDMDYSGMV"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:183",
      "retentionTimePos": "4.024516666666667",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/AMUAGNPIOKLCDR",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:64",
      "retentionTimeNeg": "4.02145",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/AMUAGNPIOKLCDR"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:66",
      "retentionTimePos": "4.024516666666667",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/AMUAGNPIOKLCDR",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:64",
      "retentionTimeNeg": "4.02145",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/AMUAGNPIOKLCDR"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:116",
      "retentionTimePos": "2.5227166666666667",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/IDKLJIUIJUVJNR",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:74",
      "retentionTimeNeg": "3.237616666666667",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/IDKLJIUIJUVJNR"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:11",
      "retentionTimePos": "4.3914",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/CVULDJMCSSACEO",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:2",
      "retentionTimeNeg": "4.390283333333333",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/CVULDJMCSSACEO"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:99",
      "retentionTimePos": "3.465816666666667",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/PQPRTPXWQQQKJC",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:29",
      "retentionTimeNeg": "3.4641666666666664",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/PQPRTPXWQQQKJC"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:15",
      "retentionTimePos": "4.281716666666667",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/OPUUICNKWUFWCM",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:47",
      "retentionTimeNeg": "4.291266666666667",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/OPUUICNKWUFWCM"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:24",
      "retentionTimePos": "4.169083333333334",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/NYOIXNGBYPQKPL",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:37",
      "retentionTimeNeg": "4.174733333333333",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/NYOIXNGBYPQKPL"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:163",
      "retentionTimePos": "4.49045",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:3",
      "retentionTimeNeg": "4.413233333333333",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:36",
      "retentionTimePos": "4.73785",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/JHXAZBBVQSRKJR",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:7",
      "retentionTimeNeg": "4.7363",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/JHXAZBBVQSRKJR"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:36",
      "retentionTimePos": "4.73785",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/JHXAZBBVQSRKJR",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:52",
      "retentionTimeNeg": "4.828266666666667",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/JHXAZBBVQSRKJR"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:61",
      "retentionTimePos": "4.413250000000001",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:3",
      "retentionTimeNeg": "4.413233333333333",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:233",
      "retentionTimePos": "2.66045",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/NPKISZUVEBESJI",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:8",
      "retentionTimeNeg": "4.390283333333333",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/NPKISZUVEBESJI"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:166",
      "retentionTimePos": "4.26635",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/NYOIXNGBYPQKPL",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:37",
      "retentionTimeNeg": "4.174733333333333",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/NYOIXNGBYPQKPL"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:287",
      "retentionTimePos": "4.079283333333334",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/CVULDJMCSSACEO",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:2",
      "retentionTimeNeg": "4.390283333333333",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/CVULDJMCSSACEO"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:117",
      "retentionTimePos": "1.4114666666666666",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/DXNCZXXFRKPEPY",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:68",
      "retentionTimeNeg": "3.7342",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/DXNCZXXFRKPEPY"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:1",
      "retentionTimePos": "3.978783333333333",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/YMAAMSKAPGRCCN",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:20",
      "retentionTimeNeg": "3.981333333333333",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/YMAAMSKAPGRCCN"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:70",
      "retentionTimePos": "1.6923333333333337",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/JPUKWEQWGBDDQB",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:16",
      "retentionTimeNeg": "1.7021666666666666",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/JPUKWEQWGBDDQB"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:245",
      "retentionTimePos": "4.475066666666667",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ZUKWGQJERAFPPP",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:118",
      "retentionTimeNeg": "4.4776",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ZUKWGQJERAFPPP"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:245",
      "retentionTimePos": "4.475066666666667",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ZUKWGQJERAFPPP",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:113",
      "retentionTimeNeg": "4.682033333333334",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ZUKWGQJERAFPPP"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:304",
      "retentionTimePos": "3.855133333333333",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ZUKWGQJERAFPPP",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:118",
      "retentionTimeNeg": "4.4776",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ZUKWGQJERAFPPP"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:304",
      "retentionTimePos": "3.855133333333333",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ZUKWGQJERAFPPP",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:113",
      "retentionTimeNeg": "4.682033333333334",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ZUKWGQJERAFPPP"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:92",
      "retentionTimePos": "3.7487",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ZUKWGQJERAFPPP",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:118",
      "retentionTimeNeg": "4.4776",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ZUKWGQJERAFPPP"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:92",
      "retentionTimePos": "3.7487",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ZUKWGQJERAFPPP",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:113",
      "retentionTimeNeg": "4.682033333333334",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ZUKWGQJERAFPPP"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:298",
      "retentionTimePos": "4.024516666666667",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ZUKWGQJERAFPPP",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:118",
      "retentionTimeNeg": "4.4776",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ZUKWGQJERAFPPP"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:298",
      "retentionTimePos": "4.024516666666667",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ZUKWGQJERAFPPP",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:113",
      "retentionTimeNeg": "4.682033333333334",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ZUKWGQJERAFPPP"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:2",
      "retentionTimePos": "4.384016666666667",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/CVULDJMCSSACEO",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:2",
      "retentionTimeNeg": "4.390283333333333",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/CVULDJMCSSACEO"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:229",
      "retentionTimePos": "4.683216666666667",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ZUKWGQJERAFPPP",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:118",
      "retentionTimeNeg": "4.4776",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ZUKWGQJERAFPPP"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:229",
      "retentionTimePos": "4.683216666666667",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ZUKWGQJERAFPPP",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:113",
      "retentionTimeNeg": "4.682033333333334",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ZUKWGQJERAFPPP"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:87",
      "retentionTimePos": "6.18905",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/FACNBZOWQDGFPB",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:55",
      "retentionTimeNeg": "6.19445",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/FACNBZOWQDGFPB"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:87",
      "retentionTimePos": "6.18905",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/FACNBZOWQDGFPB",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:119",
      "retentionTimeNeg": "6.300433333333333",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/FACNBZOWQDGFPB"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:96",
      "retentionTimePos": "4.281716666666667",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/OPUUICNKWUFWCM",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:47",
      "retentionTimeNeg": "4.291266666666667",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/OPUUICNKWUFWCM"
    },
    {
      "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:141",
      "retentionTimePos": "2.2094",
      "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/DVGGLGXQSFURLP",
      "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:28",
      "retentionTimeNeg": "2.2151666666666667",
      "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/DVGGLGXQSFURLP"
    }]

# %%
def json_to_csv(result):
    # Create a temporary CSV file
    with tempfile.NamedTemporaryFile(delete=False, mode='w', suffix='.csv', newline='') as temp_file:
        # Create a CSV writer object
        csv_writer = csv.writer(temp_file)
        
        # Check if 'results' and 'bindings' exist to avoid KeyError
        if "results" in result and "bindings" in result["results"]:
            # Extract the first row to get the headers (column names)
            headers = result["results"]["bindings"][0].keys()
            csv_writer.writerow(headers)
            
            # Write data rows
            for binding in result["results"]["bindings"]:
                row = [binding.get(column, {}).get("value", "") for column in headers]
                csv_writer.writerow(row)
        
            # Store the path for use in the return value
    temp_file_path = temp_file.name
    return temp_file_path

# %%
print(json_to_csv(result))
# Out:
# /var/folders/20/4kgcw5656h12ss_nj18mndwm0000gn/T/tmpohjtwphr.csv

# %%
import csv
import tempfile

# creating csv temp file inside the _call
with tempfile.NamedTemporaryFile(
                delete=False, mode="w", suffix=".csv", newline=""
        ) as temp_file:
            # Create a CSV writer object
    csv_writer = csv.writer(temp_file)

            # Assuming your result structure contains rows of data under 'results' key
            # Check if 'results' and 'bindings' exist to avoid KeyError
    if "results" in result and "bindings" in result["results"]:
                # Extract the first row to get the headers (column names)
        headers = result["results"]["bindings"][0].keys()
        csv_writer.writerow(headers)

                # Write data rows
        for binding in result["results"]["bindings"]:
            row = [
                        binding.get(column, {}).get("value", "") for column in headers
                    ]
            csv_writer.writerow(row)

            # Store the path for use in the return value
    temp_file_path = temp_file.name
    print("Saving results to file: ", temp_file_path)
# Out:
# Saving results to file:  /var/folders/20/4kgcw5656h12ss_nj18mndwm0000gn/T/tmpeikmxzt6.csv

# %%
import csv
import json
import tempfile

def json_to_csv(json_data):
    # Convert JSON data to Python list of dictionaries if it's a string
    if isinstance(json_data, str):
        data = json.loads(json_data)
    else:  # Assume it's already a Python list of dictionaries
        data = json_data

    # Create a temporary file
    with tempfile.NamedTemporaryFile(mode='w', delete=False, suffix='.csv', newline='') as temp_file:
        # Check if data is not empty and is a list
        if data and isinstance(data, list):
            # Extract headers from the first item assuming all items are dictionaries
            headers = data[0].keys()
            # Create a CSV writer object
            csv_writer = csv.DictWriter(temp_file, fieldnames=headers)
            # Write the header
            csv_writer.writeheader()
            # Write the rows
            csv_writer.writerows(data)
            # Store the path for use in the return value
            temp_file_path = temp_file.name
        else:
            # Handle the case where data is empty or not a list
            print("JSON data is empty or not in the expected format.")
            temp_file_path = None

    return temp_file_path

# Example usage

# %%
result2= [
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:464",
        "retentionTimePos": "1.2292333333333334",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/HOEVRHHMDJKUMZ",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:84",
        "retentionTimeNeg": "1.58195",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/HOEVRHHMDJKUMZ"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:85",
        "retentionTimePos": "1.5790666666666666",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/HOEVRHHMDJKUMZ",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:84",
        "retentionTimeNeg": "1.58195",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/HOEVRHHMDJKUMZ"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:240",
        "retentionTimePos": "2.952316666666667",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/PTQQIYXPVOPTSV",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:243",
        "retentionTimeNeg": "2.9496333333333333",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/PTQQIYXPVOPTSV"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:410",
        "retentionTimePos": "4.44905",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ANSWFKILBODRES",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:253",
        "retentionTimeNeg": "4.052933333333333",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ANSWFKILBODRES"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:84",
        "retentionTimePos": "2.5797166666666667",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/DQLOCJPJWKCPOE",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:11",
        "retentionTimeNeg": "3.1107500000000003",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/DQLOCJPJWKCPOE"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:84",
        "retentionTimePos": "2.5797166666666667",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/DQLOCJPJWKCPOE",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:248",
        "retentionTimeNeg": "3.94995",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/DQLOCJPJWKCPOE"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:84",
        "retentionTimePos": "2.5797166666666667",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/DQLOCJPJWKCPOE",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:48",
        "retentionTimeNeg": "3.3402666666666665",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/DQLOCJPJWKCPOE"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:84",
        "retentionTimePos": "2.5797166666666667",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/DQLOCJPJWKCPOE",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:85",
        "retentionTimeNeg": "3.6826",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/DQLOCJPJWKCPOE"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:84",
        "retentionTimePos": "2.5797166666666667",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/DQLOCJPJWKCPOE",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:147",
        "retentionTimeNeg": "2.458916666666666",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/DQLOCJPJWKCPOE"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:84",
        "retentionTimePos": "2.5797166666666667",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/DQLOCJPJWKCPOE",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:215",
        "retentionTimeNeg": "2.585033333333333",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/DQLOCJPJWKCPOE"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:130",
        "retentionTimePos": "2.3292333333333333",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/XGADTAYOFHOFIW",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:116",
        "retentionTimeNeg": "2.2449166666666667",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/XGADTAYOFHOFIW"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:130",
        "retentionTimePos": "2.3292333333333333",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/XGADTAYOFHOFIW",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:6",
        "retentionTimeNeg": "2.328966666666666",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/XGADTAYOFHOFIW"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:143",
        "retentionTimePos": "4.5575",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:164",
        "retentionTimeNeg": "3.690116666666667",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:143",
        "retentionTimePos": "4.5575",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:172",
        "retentionTimeNeg": "4.411600000000001",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:143",
        "retentionTimePos": "4.5575",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:226",
        "retentionTimeNeg": "4.6238166666666665",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:132",
        "retentionTimePos": "4.621833333333333",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:164",
        "retentionTimeNeg": "3.690116666666667",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:132",
        "retentionTimePos": "4.621833333333333",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:172",
        "retentionTimeNeg": "4.411600000000001",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:132",
        "retentionTimePos": "4.621833333333333",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:226",
        "retentionTimeNeg": "4.6238166666666665",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:364",
        "retentionTimePos": "1.7661",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/DKZBBWMURDFHNE",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:143",
        "retentionTimeNeg": "1.76635",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/DKZBBWMURDFHNE"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:179",
        "retentionTimePos": "6.401",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/RCRIEGZGQYGDDM",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:108",
        "retentionTimeNeg": "6.58255",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/RCRIEGZGQYGDDM"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:179",
        "retentionTimePos": "6.401",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/RCRIEGZGQYGDDM",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:9",
        "retentionTimeNeg": "6.409166666666667",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/RCRIEGZGQYGDDM"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:535",
        "retentionTimePos": "6.578833333333334",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/RCRIEGZGQYGDDM",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:108",
        "retentionTimeNeg": "6.58255",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/RCRIEGZGQYGDDM"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:535",
        "retentionTimePos": "6.578833333333334",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/RCRIEGZGQYGDDM",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:9",
        "retentionTimeNeg": "6.409166666666667",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/RCRIEGZGQYGDDM"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:225",
        "retentionTimePos": "5.000966666666667",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/LUZSWWYKKLTDHU",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:62",
        "retentionTimeNeg": "4.9133",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/LUZSWWYKKLTDHU"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:186",
        "retentionTimePos": "5.046933333333333",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/LUZSWWYKKLTDHU",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:62",
        "retentionTimeNeg": "4.9133",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/LUZSWWYKKLTDHU"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:23",
        "retentionTimePos": "4.836416666666667",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/LUZSWWYKKLTDHU",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:62",
        "retentionTimeNeg": "4.9133",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/LUZSWWYKKLTDHU"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:266",
        "retentionTimePos": "4.052433333333333",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/RCMABBHQYMBYKV",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:155",
        "retentionTimeNeg": "4.052933333333333",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/RCMABBHQYMBYKV"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:266",
        "retentionTimePos": "4.052433333333333",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/RCMABBHQYMBYKV",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:55",
        "retentionTimeNeg": "3.563283333333333",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/RCMABBHQYMBYKV"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:266",
        "retentionTimePos": "4.052433333333333",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/RCMABBHQYMBYKV",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:148",
        "retentionTimeNeg": "4.44895",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/RCMABBHQYMBYKV"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:287",
        "retentionTimePos": "2.885383333333333",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/JHXAZBBVQSRKJR",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:24",
        "retentionTimeNeg": "4.8358333333333325",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/JHXAZBBVQSRKJR"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:287",
        "retentionTimePos": "2.885383333333333",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/JHXAZBBVQSRKJR",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:14",
        "retentionTimeNeg": "4.73675",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/JHXAZBBVQSRKJR"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:287",
        "retentionTimePos": "2.885383333333333",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/JHXAZBBVQSRKJR",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:29",
        "retentionTimeNeg": "4.68605",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/JHXAZBBVQSRKJR"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:39",
        "retentionTimePos": "4.920116666666667",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/LUZSWWYKKLTDHU",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:62",
        "retentionTimeNeg": "4.9133",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/LUZSWWYKKLTDHU"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:139",
        "retentionTimePos": "3.56325",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:164",
        "retentionTimeNeg": "3.690116666666667",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:139",
        "retentionTimePos": "3.56325",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:172",
        "retentionTimeNeg": "4.411600000000001",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:139",
        "retentionTimePos": "3.56325",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:226",
        "retentionTimeNeg": "4.6238166666666665",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:187",
        "retentionTimePos": "3.6476166666666665",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:164",
        "retentionTimeNeg": "3.690116666666667",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:187",
        "retentionTimePos": "3.6476166666666665",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:172",
        "retentionTimeNeg": "4.411600000000001",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:187",
        "retentionTimePos": "3.6476166666666665",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:226",
        "retentionTimeNeg": "4.6238166666666665",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:552",
        "retentionTimePos": "3.181666666666666",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/RCMABBHQYMBYKV",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:155",
        "retentionTimeNeg": "4.052933333333333",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/RCMABBHQYMBYKV"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:552",
        "retentionTimePos": "3.181666666666666",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/RCMABBHQYMBYKV",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:55",
        "retentionTimeNeg": "3.563283333333333",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/RCMABBHQYMBYKV"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:552",
        "retentionTimePos": "3.181666666666666",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/RCMABBHQYMBYKV",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:148",
        "retentionTimeNeg": "4.44895",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/RCMABBHQYMBYKV"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:799",
        "retentionTimePos": "2.9305000000000003",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/NFABMCCMPXXBFY",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:177",
        "retentionTimeNeg": "3.5550833333333336",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/NFABMCCMPXXBFY"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:386",
        "retentionTimePos": "3.4682000000000004",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/PQPRTPXWQQQKJC",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:86",
        "retentionTimeNeg": "3.46975",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/PQPRTPXWQQQKJC"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:259",
        "retentionTimePos": "6.892",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/UQFZKTIHSICSPG",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:290",
        "retentionTimeNeg": "7.363133333333334",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/UQFZKTIHSICSPG"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:770",
        "retentionTimePos": "6.995500000000001",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/UQFZKTIHSICSPG",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:290",
        "retentionTimeNeg": "7.363133333333334",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/UQFZKTIHSICSPG"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:835",
        "retentionTimePos": "6.013733333333334",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/UQFZKTIHSICSPG",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:290",
        "retentionTimeNeg": "7.363133333333334",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/UQFZKTIHSICSPG"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:28",
        "retentionTimePos": "4.739116666666666",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/JHXAZBBVQSRKJR",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:24",
        "retentionTimeNeg": "4.8358333333333325",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/JHXAZBBVQSRKJR"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:28",
        "retentionTimePos": "4.739116666666666",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/JHXAZBBVQSRKJR",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:14",
        "retentionTimeNeg": "4.73675",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/JHXAZBBVQSRKJR"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:28",
        "retentionTimePos": "4.739116666666666",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/JHXAZBBVQSRKJR",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:29",
        "retentionTimeNeg": "4.68605",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/JHXAZBBVQSRKJR"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:298",
        "retentionTimePos": "2.4112666666666667",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/CNKGXSBPJQHCKK",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:15",
        "retentionTimeNeg": "2.41945",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/CNKGXSBPJQHCKK"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:344",
        "retentionTimePos": "1.26885",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/HAVWRBANWNTOJX",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:119",
        "retentionTimeNeg": "1.27065",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/HAVWRBANWNTOJX"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:9",
        "retentionTimePos": "2.3292333333333333",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/XGADTAYOFHOFIW",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:116",
        "retentionTimeNeg": "2.2449166666666667",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/XGADTAYOFHOFIW"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:9",
        "retentionTimePos": "2.3292333333333333",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/XGADTAYOFHOFIW",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:6",
        "retentionTimeNeg": "2.328966666666666",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/XGADTAYOFHOFIW"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:331",
        "retentionTimePos": "4.052433333333333",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:164",
        "retentionTimeNeg": "3.690116666666667",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:331",
        "retentionTimePos": "4.052433333333333",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:172",
        "retentionTimeNeg": "4.411600000000001",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:331",
        "retentionTimePos": "4.052433333333333",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:226",
        "retentionTimeNeg": "4.6238166666666665",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:401",
        "retentionTimePos": "3.4682000000000004",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/RFHOXTWWHVRIKG",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:198",
        "retentionTimeNeg": "3.46975",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/RFHOXTWWHVRIKG"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:728",
        "retentionTimePos": "4.096233333333333",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/WMIKDZKELUVXGM",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:277",
        "retentionTimeNeg": "3.7508166666666662",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/WMIKDZKELUVXGM"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:616",
        "retentionTimePos": "1.089",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/CRSFLLTWRCYNNX",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:165",
        "retentionTimeNeg": "1.0961833333333333",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/CRSFLLTWRCYNNX"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:48",
        "retentionTimePos": "3.3383166666666666",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/DQLOCJPJWKCPOE",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:11",
        "retentionTimeNeg": "3.1107500000000003",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/DQLOCJPJWKCPOE"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:48",
        "retentionTimePos": "3.3383166666666666",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/DQLOCJPJWKCPOE",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:248",
        "retentionTimeNeg": "3.94995",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/DQLOCJPJWKCPOE"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:48",
        "retentionTimePos": "3.3383166666666666",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/DQLOCJPJWKCPOE",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:48",
        "retentionTimeNeg": "3.3402666666666665",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/DQLOCJPJWKCPOE"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:48",
        "retentionTimePos": "3.3383166666666666",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/DQLOCJPJWKCPOE",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:85",
        "retentionTimeNeg": "3.6826",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/DQLOCJPJWKCPOE"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:48",
        "retentionTimePos": "3.3383166666666666",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/DQLOCJPJWKCPOE",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:147",
        "retentionTimeNeg": "2.458916666666666",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/DQLOCJPJWKCPOE"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:48",
        "retentionTimePos": "3.3383166666666666",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/DQLOCJPJWKCPOE",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:215",
        "retentionTimeNeg": "2.585033333333333",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/DQLOCJPJWKCPOE"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:439",
        "retentionTimePos": "3.3383166666666666",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/PLYCKVKDTOBZTL",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:12",
        "retentionTimeNeg": "3.3402666666666665",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/PLYCKVKDTOBZTL"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:439",
        "retentionTimePos": "3.3383166666666666",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/PLYCKVKDTOBZTL",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:26",
        "retentionTimeNeg": "3.59575",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/PLYCKVKDTOBZTL"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:722",
        "retentionTimePos": "3.1199166666666667",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/RCMABBHQYMBYKV",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:155",
        "retentionTimeNeg": "4.052933333333333",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/RCMABBHQYMBYKV"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:722",
        "retentionTimePos": "3.1199166666666667",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/RCMABBHQYMBYKV",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:55",
        "retentionTimeNeg": "3.563283333333333",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/RCMABBHQYMBYKV"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:722",
        "retentionTimePos": "3.1199166666666667",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/RCMABBHQYMBYKV",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:148",
        "retentionTimeNeg": "4.44895",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/RCMABBHQYMBYKV"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:181",
        "retentionTimePos": "2.885383333333333",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/MDIUMSLCYIJBQC",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:109",
        "retentionTimeNeg": "3.3334",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/MDIUMSLCYIJBQC"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:181",
        "retentionTimePos": "2.885383333333333",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/MDIUMSLCYIJBQC",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:59",
        "retentionTimeNeg": "3.12655",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/MDIUMSLCYIJBQC"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:181",
        "retentionTimePos": "2.885383333333333",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/MDIUMSLCYIJBQC",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:64",
        "retentionTimeNeg": "3.177633333333333",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/MDIUMSLCYIJBQC"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:181",
        "retentionTimePos": "2.885383333333333",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/MDIUMSLCYIJBQC",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:19",
        "retentionTimeNeg": "2.8838166666666667",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/MDIUMSLCYIJBQC"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:267",
        "retentionTimePos": "4.456033333333334",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:164",
        "retentionTimeNeg": "3.690116666666667",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:267",
        "retentionTimePos": "4.456033333333334",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:172",
        "retentionTimeNeg": "4.411600000000001",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:267",
        "retentionTimePos": "4.456033333333334",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:226",
        "retentionTimeNeg": "4.6238166666666665",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:405",
        "retentionTimePos": "1.7512166666666666",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/HHXMOTDTSDYYEI",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:103",
        "retentionTimeNeg": "2.068383333333333",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/HHXMOTDTSDYYEI"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:405",
        "retentionTimePos": "1.7512166666666666",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/HHXMOTDTSDYYEI",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:146",
        "retentionTimeNeg": "1.89865",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/HHXMOTDTSDYYEI"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:406",
        "retentionTimePos": "5.721566666666666",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/OWRZLPFARZIZOG",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:138",
        "retentionTimeNeg": "4.68605",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/OWRZLPFARZIZOG"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:406",
        "retentionTimePos": "5.721566666666666",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/OWRZLPFARZIZOG",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:129",
        "retentionTimeNeg": "4.752466666666667",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/OWRZLPFARZIZOG"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_pos.mgf:scan:606",
        "retentionTimePos": "6.644283333333333",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/OFFZRQDMDYSGMV",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_A06_features_ms2_neg.mgf:scan:22",
        "retentionTimeNeg": "6.895216666666667",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/OFFZRQDMDYSGMV"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:183",
        "retentionTimePos": "4.024516666666667",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/AMUAGNPIOKLCDR",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:64",
        "retentionTimeNeg": "4.02145",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/AMUAGNPIOKLCDR"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:66",
        "retentionTimePos": "4.024516666666667",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/AMUAGNPIOKLCDR",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:64",
        "retentionTimeNeg": "4.02145",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/AMUAGNPIOKLCDR"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:116",
        "retentionTimePos": "2.5227166666666667",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/IDKLJIUIJUVJNR",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:74",
        "retentionTimeNeg": "3.237616666666667",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/IDKLJIUIJUVJNR"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:11",
        "retentionTimePos": "4.3914",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/CVULDJMCSSACEO",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:2",
        "retentionTimeNeg": "4.390283333333333",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/CVULDJMCSSACEO"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:99",
        "retentionTimePos": "3.465816666666667",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/PQPRTPXWQQQKJC",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:29",
        "retentionTimeNeg": "3.4641666666666664",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/PQPRTPXWQQQKJC"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:15",
        "retentionTimePos": "4.281716666666667",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/OPUUICNKWUFWCM",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:47",
        "retentionTimeNeg": "4.291266666666667",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/OPUUICNKWUFWCM"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:24",
        "retentionTimePos": "4.169083333333334",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/NYOIXNGBYPQKPL",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:37",
        "retentionTimeNeg": "4.174733333333333",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/NYOIXNGBYPQKPL"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:163",
        "retentionTimePos": "4.49045",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:3",
        "retentionTimeNeg": "4.413233333333333",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:36",
        "retentionTimePos": "4.73785",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/JHXAZBBVQSRKJR",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:7",
        "retentionTimeNeg": "4.7363",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/JHXAZBBVQSRKJR"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:36",
        "retentionTimePos": "4.73785",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/JHXAZBBVQSRKJR",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:52",
        "retentionTimeNeg": "4.828266666666667",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/JHXAZBBVQSRKJR"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:61",
        "retentionTimePos": "4.413250000000001",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:3",
        "retentionTimeNeg": "4.413233333333333",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ACHDMUPTZYZIGR"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:233",
        "retentionTimePos": "2.66045",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/NPKISZUVEBESJI",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:8",
        "retentionTimeNeg": "4.390283333333333",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/NPKISZUVEBESJI"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:166",
        "retentionTimePos": "4.26635",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/NYOIXNGBYPQKPL",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:37",
        "retentionTimeNeg": "4.174733333333333",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/NYOIXNGBYPQKPL"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:287",
        "retentionTimePos": "4.079283333333334",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/CVULDJMCSSACEO",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:2",
        "retentionTimeNeg": "4.390283333333333",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/CVULDJMCSSACEO"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:117",
        "retentionTimePos": "1.4114666666666666",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/DXNCZXXFRKPEPY",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:68",
        "retentionTimeNeg": "3.7342",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/DXNCZXXFRKPEPY"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:1",
        "retentionTimePos": "3.978783333333333",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/YMAAMSKAPGRCCN",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:20",
        "retentionTimeNeg": "3.981333333333333",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/YMAAMSKAPGRCCN"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:70",
        "retentionTimePos": "1.6923333333333337",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/JPUKWEQWGBDDQB",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:16",
        "retentionTimeNeg": "1.7021666666666666",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/JPUKWEQWGBDDQB"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:245",
        "retentionTimePos": "4.475066666666667",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ZUKWGQJERAFPPP",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:118",
        "retentionTimeNeg": "4.4776",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ZUKWGQJERAFPPP"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:245",
        "retentionTimePos": "4.475066666666667",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ZUKWGQJERAFPPP",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:113",
        "retentionTimeNeg": "4.682033333333334",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ZUKWGQJERAFPPP"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:304",
        "retentionTimePos": "3.855133333333333",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ZUKWGQJERAFPPP",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:118",
        "retentionTimeNeg": "4.4776",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ZUKWGQJERAFPPP"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:304",
        "retentionTimePos": "3.855133333333333",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ZUKWGQJERAFPPP",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:113",
        "retentionTimeNeg": "4.682033333333334",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ZUKWGQJERAFPPP"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:92",
        "retentionTimePos": "3.7487",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ZUKWGQJERAFPPP",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:118",
        "retentionTimeNeg": "4.4776",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ZUKWGQJERAFPPP"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:92",
        "retentionTimePos": "3.7487",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ZUKWGQJERAFPPP",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:113",
        "retentionTimeNeg": "4.682033333333334",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ZUKWGQJERAFPPP"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:298",
        "retentionTimePos": "4.024516666666667",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ZUKWGQJERAFPPP",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:118",
        "retentionTimeNeg": "4.4776",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ZUKWGQJERAFPPP"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:298",
        "retentionTimePos": "4.024516666666667",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ZUKWGQJERAFPPP",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:113",
        "retentionTimeNeg": "4.682033333333334",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ZUKWGQJERAFPPP"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:2",
        "retentionTimePos": "4.384016666666667",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/CVULDJMCSSACEO",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:2",
        "retentionTimeNeg": "4.390283333333333",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/CVULDJMCSSACEO"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:229",
        "retentionTimePos": "4.683216666666667",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ZUKWGQJERAFPPP",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:118",
        "retentionTimeNeg": "4.4776",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ZUKWGQJERAFPPP"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:229",
        "retentionTimePos": "4.683216666666667",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/ZUKWGQJERAFPPP",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:113",
        "retentionTimeNeg": "4.682033333333334",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/ZUKWGQJERAFPPP"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:87",
        "retentionTimePos": "6.18905",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/FACNBZOWQDGFPB",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:55",
        "retentionTimeNeg": "6.19445",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/FACNBZOWQDGFPB"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:87",
        "retentionTimePos": "6.18905",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/FACNBZOWQDGFPB",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:119",
        "retentionTimeNeg": "6.300433333333333",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/FACNBZOWQDGFPB"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:96",
        "retentionTimePos": "4.281716666666667",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/OPUUICNKWUFWCM",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:47",
        "retentionTimeNeg": "4.291266666666667",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/OPUUICNKWUFWCM"
      },
      {
        "featurePos": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_pos.mgf:scan:141",
        "retentionTimePos": "2.2094",
        "InChIKey2DPos": "https://enpkg.commons-lab.org/kg/DVGGLGXQSFURLP",
        "featureNeg": "https://enpkg.commons-lab.org/kg/lcms_feature_mzspec:MSV000087728:VGF156_B06_features_ms2_neg.mgf:scan:28",
        "retentionTimeNeg": "2.2151666666666667",
        "InChIKey2DNeg": "https://enpkg.commons-lab.org/kg/DVGGLGXQSFURLP"
      }
    ]

# %%
def json_to_csv(json_data):
        # Convert JSON data to Python list of dictionaries if it's a string
        if isinstance(json_data, str):
            data = json.loads(json_data)
        else:  # Assume it's already a Python list of dictionaries
            data = json_data

        # Create a temporary file
        with tempfile.NamedTemporaryFile(
            mode="w", delete=True, suffix=".csv", newline=""
        ) as temp_file:
            # Check if data is not empty and is a list
            if data and isinstance(data, list):
                # Extract headers from the first item assuming all items are dictionaries
                headers = data[0].keys()
                # Create a CSV writer object
                csv_writer = csv.DictWriter(temp_file, fieldnames=headers)
                # Write the header
                csv_writer.writeheader()
                # Write the rows
                csv_writer.writerows(data)
                # Store the path for use in the return value
                temp_file_path = temp_file.name
            else:
                # Handle the case where data is empty or not a list
                print("JSON data is empty or not in the expected format.")
                temp_file_path = None

        return temp_file_path

# %%
 path=json_to_csv(result2)

# %%
print(path)
# Out:
# /var/folders/20/4kgcw5656h12ss_nj18mndwm0000gn/T/tmp1auytax3.csv

# %% [markdown]
# print(path)

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import asyncio

# Define the asynchronous function to analyze and plot data from a CSV file
async def analyze_csv_data(file_path: str, user_request: str) -> None:
    # Read the CSV file into a pandas DataFrame
    df = pd.read_csv(file_path)
    
    # Placeholder for analysis logic - this would be replaced with actual analysis based on 'user_request'
    # Here, I'm assuming the request might be to plot some generic data, for example, a histogram of the first numerical column found
    # In a real scenario, this part should be replaced or expanded based on the types of requests you expect.
    
    if user_request == "plot histogram":
        # Find the first numerical column
        numerical_col = None
        for col in df.columns:
            if pd.api.types.is_numeric_dtype(df[col]):
                numerical_col = col
                break
        
        # If a numerical column is found, plot a histogram
        if numerical_col:
            plt.figure()
            df[numerical_col].hist()
            plt.title(f'Histogram of {numerical_col}')
            plt.show()
        else:
            print("No numerical columns found for plotting a histogram.")
    else:
        # Here you can add more conditions based on different user requests
        print(f"Request '{user_request}' is not recognized.")

# This function is just a structure and should be adapted to your specific analysis needs.

# The following is a test call, comment out when implementing in actual code.
# asyncio.run(analyze_csv_data("path_to_your_file.csv", "plot histogram"))

# %% [markdown]
# ## Testing codebox/future interpreter agent

# %%
import os
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_PROJECT"] = f"KGBot Testing - codebox" #Please update the name here if you want to create a new project for separating the traces. 
os.environ["LANGCHAIN_ENDPOINT"] = "https://api.smith.langchain.com"
from langsmith import Client
client = Client()

# #Check if the client was initialized
print(client)
from codeinterpreterapi import CodeInterpreterSession, File


def main(path, question, sparql_query) -> None:
    # context manager for start/stop of the session
    with CodeInterpreterSession() as session:
        # define the user request
        user_request = f"Please review the provided dataset and the following SPARQL query:{sparql_query} which was used to query the knowledge graph to answer to the question : {question}. The dataset was provided by the knowledge graph as a response to the question. Your task is to summarize the key findings from the dataset succinctly and provide a clear, concise answer to the question: {question}. Indicate the format of the dataset for appropriate handling. "
        files = [
            File.from_path(path),
        ]

        # generate the response
        response = session.generate_response(user_request, files=files)

        # output the response (text + image)
        response.show()
# Out:
# Client (API URL: https://api.smith.langchain.com)

# %%
#Checking the packages
def main() -> None:
    # context manager for start/stop of the session
    with CodeInterpreterSession() as session:
        # Python script to list installed packages and write them to a file
        python_code_to_list_packages = """
import pkg_resources
# List of installed packages and their versions
installed_packages_list = [(d.project_name, d.version) for d in pkg_resources.working_set]
# Generate pip requirements file content
pip_requirements_content = '\\n'.join([f"{pkg}=={ver}" for pkg, ver in installed_packages_list])
# Writing to files
pip_file_path = '/mnt/data/pip_requirements.txt'
with open(pip_file_path, 'w') as f:
    f.write(pip_requirements_content)
print('Installed packages list has been written to /mnt/data/pip_requirements.txt')
with open(pip_file_path, 'r') as f:
    pip_requirements_content = f.read()
print(pip_requirements_content)
        """

        # Define the user request to execute the provided Python code
        user_request = "Please execute the following Python code to list all installed packages in the CodeBox environment and write them to a file: " + python_code_to_list_packages

        # No need to attach files for this specific request
        files = []  # Adjust based on whether you need to attach files

        # Generate the response
        response = session.generate_response(user_request, files=files)

        # Output the response (text)
        response.show()

print(main())
# Out:
# INFO: Using a LocalBox which is not fully isolated
#       and not scalable across multiple users.
#       Make sure to use a CODEBOX_API_KEY in production.
#       Set envar SHOW_INFO=False to not see this again.
# 2024-03-13 13:00:59,754 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-03-13 13:01:04,193 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-03-13 13:01:05,417 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-03-13 13:01:07,135 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# AI:  The list of installed packages has been successfully written to the file 'pip_requirements.txt'. If you need further assistance or modifications, feel free to ask!
# File:  pip_requirements.txt
# ---------------------------------------------------------------------------
# ...

# %%
import os
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_PROJECT"] = f"KGBot Testing - codebox" #Please update the name here if you want to create a new project for separating the traces. 
os.environ["LANGCHAIN_ENDPOINT"] = "https://api.smith.langchain.com"
from langsmith import Client
client = Client()

# #Check if the client was initialized
print(client)
from codeinterpreterapi import CodeInterpreterSession, File


def main(path, question) -> None:
    # context manager for start/stop of the session
    with CodeInterpreterSession() as session:
        # define the user request
        user_request = f"Please review the provided dataset to answer to the question : {question}. Your task is to summarize the key findings from the dataset succinctly and provide a clear, concise answer to the question: {question}. If it is needed to visualize the answer generate a plot or graph or a bar chart. Indicate the format of the dataset for appropriate handling. "
        files = [
            File.from_path(path),
        ]

        # generate the response
        response = session.generate_response(user_request, files=files)

        # output the response (text + image)
        response.show()
# Out:
# ---------------------------------------------------------------------------
# LangSmithUserError                        Traceback (most recent call last)
# Cell In[2], line 6
#       4 os.environ["LANGCHAIN_ENDPOINT"] = "https://api.smith.langchain.com"
#       5 from langsmith import Client
# ----> 6 client = Client()
#       8 # #Check if the client was initialized
#       9 print(client)
#
# File ~/anaconda3/envs/kgai/lib/python3.11/site-packages/langsmith/client.py:414, in Client.__init__(self, api_url, api_key, retry_config, timeout_ms, web_url, session, auto_batch_tracing)
#     412 self.api_key = _get_api_key(api_key)
#     413 self.api_url = _get_api_url(api_url, self.api_key)
# --> 414 _validate_api_key_if_hosted(self.api_url, self.api_key)
#     415 self.retry_config = retry_config or _default_retry_config()
#     416 self.timeout_ms = timeout_ms or 10000
#
# ...

# %%
path="/Users/madinabekbergenova/Downloads/Book.xlsx"
question="How many hours on average do children watch TV in the UK?"
main(path, question)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 path="/Users/madinabekbergenova/Downloads/Book.xlsx"
#       2 question="How many hours on average do children watch TV in the UK?"
# ----> 3 main(path, question)
#
# NameError: name 'main' is not defined

# %%
path="/var/folders/20/4kgcw5656h12ss_nj18mndwm0000gn/T/tmprhzardl4.csv"
question="Which extracts have features (pos ionization mode) annotated as the class, aspidosperma-type alkaloids, by CANOPUS with a probability score above 0.5, ordered by the decreasing count of features as aspidosperma-type alkaloids? Group by extract." 
sparql_query="""PREFIX ns1: <https://enpkg.commons-lab.org/module/>
PREFIX ns2: <https://enpkg.commons-lab.org/kg/>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

SELECT ?extract (COUNT(?feature) AS ?count)
WHERE {
    # ?extract a ns2:LabExtract ;
             ns2:has_LCMS ?analysis .
    # ?analysis a ns2:LCMSAnalysisPos ;
              ns2:has_lcms_feature_list ?featureList .
    # ?featureList ns2:has_lcms_feature ?feature .
    # ?feature ns2:has_canopus_annotation ?annotation .
    # ?annotation a ns2:SiriusCanopusAnnotation ;
                ns2:has_canopus_npc_class <https://enpkg.commons-lab.org/kg/npc_Aspidosperma_type> ;
                ns2:has_canopus_npc_class_prob ?prob .
    FILTER (?prob > 0.5)
}
GROUP BY ?extract
ORDER BY DESC(?count)"""
main(path, question, sparql_query)
# Out:
# INFO: Using a LocalBox which is not fully isolated
#       and not scalable across multiple users.
#       Make sure to use a CODEBOX_API_KEY in production.
#       Set envar SHOW_INFO=False to not see this again.
# AI:  The dataset contains two columns: "extract" and "count." Each row represents an extract with the corresponding count of features annotated as aspidosperma-type alkaloids by CANOPUS with a probability score above 0.5.
#
# Based on the dataset, the extracts with features annotated as aspidosperma-type alkaloids by CANOPUS with a probability score above 0.5, ordered by the decreasing count of features, are as follows:
#
# 1. Extract: https://enpkg.commons-lab.org/kg/VGF152_B02, Count: 74
# 2. Extract: https://enpkg.commons-lab.org/kg/VGF157_D02, Count: 11
# 3. Extract: https://enpkg.commons-lab.org/kg/VGF147_B11, Count: 10
# 4. Extract: https://enpkg.commons-lab.org/kg/VGF153_C03, Count: 7
# 5. Extract: https://enpkg.commons-lab.org/kg/VGF157_E02, Count: 2
#
# ...

# %%
def interpreter_logic(question, generated_sparql_query, file_path) -> None:
    # context manager for start/stop of the session
    # define the user request
    print(f"Interpreting {question}")
    print(f"SPARQL query: {generated_sparql_query}")
    print(f"File path: {file_path}")
    with CodeInterpreterSession() as session:
        user_request = f"""You are an interpreter agent. Your task is to analyze the output related to a SPARQL query, which could be in two forms:
         If the output of the Sparql_query_runner agent is only the dictionary containing question: "{question}", generated SPARQL query: "{generated_sparql_query}" which was used to query the knowledge graph to answer to the question and path: "{file_path}" containing the SPARQL output then you should review the provided dataset from the file and SPARQL query to provide a clear, concise answer to the question. Additionally, if visualization of the results is necessary (e.g., when the SPARQL output is large or complex), you should provide an appropriate visualization, such as a bar chart, diagram, or plot, to effectively communicate the answer.
         If the output of the Sparql_query_runner agent contains the answer to the question together with the dictionary containing the question: "{question}", generated SPARQL query: "{generated_sparql_query}" and path: "{file_path}", then you should analyze this output and provide visualization of the answer to the question. 
         The type of visualization – bar chart, diagram, or plot – will depend on the nature of the SPARQL output and the best way to represent the answer to the question clearly.
         Submit only the final answer to the supervisor. Indicate the format of the dataset for appropriate handling. """
        files = [
            File.from_path(file_path),
        ]
    
        # generate the response
        response = session.generate_response(user_request, files=files)
        # output the response (text + image)
        response.show()
        return response.content

# %%
##trying q2 with the function the same as in  kgbot
path= "/var/folders/20/4kgcw5656h12ss_nj18mndwm0000gn/T/tmpd0cxwb2w.csv"
question="Which extracts have features (pos ionization mode) annotated as the class, aspidosperma-type alkaloids, by CANOPUS with a probability score above 0.5, ordered by the decreasing count of features as aspidosperma-type alkaloids? Group by extract and provide a bar chart."
sparql_query=""" PREFIX ns1: <https://enpkg.commons-lab.org/kg/>
PREFIX ns2: <https://enpkg.commons-lab.org/module/>
SELECT ?extract (COUNT(?feature) AS ?count)
WHERE {
    # ?extract ns1:has_LCMS ?analysis .
    # ?analysis a ns1:LCMSAnalysisPos .
    # ?analysis ns1:has_lcms_feature_list ?featureList .
    # ?featureList ns1:has_lcms_feature ?feature .
    # ?feature ns1:has_canopus_annotation ?annotation .
    # ?annotation a ns1:SiriusCanopusAnnotation .
    # ?annotation ns1:has_canopus_npc_class ns1:npc_Aspidosperma_type .
    # ?annotation ns1:has_canopus_npc_class_prob ?prob .
    FILTER(?prob > 0.5)
}
GROUP BY ?extract
ORDER BY DESC(?count) """
result=interpreter_logic(question, sparql_query, path)
print(result)
# Out:
# Interpreting Which extracts have features (pos ionization mode) annotated as the class, aspidosperma-type alkaloids, by CANOPUS with a probability score above 0.5, ordered by the decreasing count of features as aspidosperma-type alkaloids? Group by extract and provide a bar chart.
# SPARQL query:  PREFIX ns1: <https://enpkg.commons-lab.org/kg/>
# PREFIX ns2: <https://enpkg.commons-lab.org/module/>
# SELECT ?extract (COUNT(?feature) AS ?count)
# WHERE {
#     ?extract ns1:has_LCMS ?analysis .
#     ?analysis a ns1:LCMSAnalysisPos .
#     ?analysis ns1:has_lcms_feature_list ?featureList .
#     ?featureList ns1:has_lcms_feature ?feature .
#     ?feature ns1:has_canopus_annotation ?annotation .
#     ?annotation a ns1:SiriusCanopusAnnotation .
#     ?annotation ns1:has_canopus_npc_class ns1:npc_Aspidosperma_type .
#     ?annotation ns1:has_canopus_npc_class_prob ?prob .
#     FILTER(?prob > 0.5)
# }
# GROUP BY ?extract
# ORDER BY DESC(?count)
# ...

# %%
##trying q7
path="/var/folders/20/4kgcw5656h12ss_nj18mndwm0000gn/T/tmppywj4re0.csv"
question="For features from the Melochia umbellata taxon in pos ionization mode with SIRIUS annotations, get the ones for which a feature in neg ionization mode with the same retention time (+/- 3 seconds) has the same SIRIUS annotation by comparing the InCHIKey 2D. Return the features, retention times, and InChIKey2D"
sparql_query="""PREFIX ns1: <https://enpkg.commons-lab.org/module/>
PREFIX ns2: <https://enpkg.commons-lab.org/kg/>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

SELECT ?featurePos ?retentionTimePos ?InChIKey2DPos ?featureNeg ?retentionTimeNeg ?InChIKey2DNeg
WHERE {
    # ?rawMaterial ns2:has_wd_id <http://www.wikidata.org/entity/Q6813281> .
    # ?rawMaterial ns2:has_lab_process ?labExtract .
    # ?labExtract ns2:has_LCMS ?lcmsAnalysisPos .
    # ?lcmsAnalysisPos a ns2:LCMSAnalysisPos .
    # ?lcmsAnalysisPos ns2:has_lcms_feature_list ?lcmsFeatureListPos .
    # ?lcmsFeatureListPos ns2:has_lcms_feature ?featurePos .
    # ?featurePos ns2:has_retention_time ?retentionTimePos .
    # ?featurePos ns2:has_sirius_annotation ?siriusAnnotationPos .
    # ?siriusAnnotationPos ns2:has_InChIkey2D ?InChIKey2DPos .
    
    # ?labExtract ns2:has_LCMS ?lcmsAnalysisNeg .
    # ?lcmsAnalysisNeg a ns2:LCMSAnalysisNeg .
    # ?lcmsAnalysisNeg ns2:has_lcms_feature_list ?lcmsFeatureListNeg .
    # ?lcmsFeatureListNeg ns2:has_lcms_feature ?featureNeg .
    # ?featureNeg ns2:has_retention_time ?retentionTimeNeg .
    # ?featureNeg ns2:has_sirius_annotation ?siriusAnnotationNeg .
    # ?siriusAnnotationNeg ns2:has_InChIkey2D ?InChIKey2DNeg .
    
    FILTER (?InChIKey2DPos = ?InChIKey2DNeg)
    FILTER (abs(?retentionTimePos - ?retentionTimeNeg) <= 3)
}"""

#main(path, question, sparql_query)

# %% [markdown]
# ## Counting tokens

# %%
from RdfGraphCustom import RdfGraph
tokens_output=RdfGraph.token_counter(sparql_query)
print(tokens_output)
question_tokens=RdfGraph.token_counter(question)
print(question_tokens)
# Out:
# 429
# 80

# %%
import json
from RdfGraphCustom import RdfGraph
# Convert the SPARQL query output to a string if it's not already
if isinstance(result2, dict):  # Assuming result2 is a dictionary (JSON)
    result2_string = json.dumps(result2)
else:
    result2_string = str(result2)  # Make sure it's a string if it's not a dictionary

# Now call the token_counter method with the string
tokens_result = RdfGraph.token_counter(result2_string)
print(tokens_result)
# Out:
# 19863

# %%
#tryingbthe code thta was generated by interpreter agent
import pandas as pd# Load the dataset
df = pd.read_csv('/var/folders/20/4kgcw5656h12ss_nj18mndwm0000gn/T/tmpd0cxwb2w.csv')# Display the first few rows of the dataset\\
df.head()
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6))
plt.bar(df['extract'], df['count'])
plt.xlabel('Extract')
plt.ylabel('Feature Count')
plt.title('Feature Counts for Different Extracts')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# 2024-03-14 11:45:46,676 - INFO - Note: NumExpr detected 14 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 2024-03-14 11:45:46,676 - INFO - NumExpr defaulting to 8 threads.
